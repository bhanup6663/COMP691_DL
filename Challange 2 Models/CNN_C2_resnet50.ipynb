# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset,DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 29878814.49it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [7 2]

# %%
model = models.resnet50(pretrained=True)

num_classes = 10  
dropout_rate = 0.5  

# Modify the fully connected layer
model.fc = nn.Sequential(
    nn.Dropout(dropout_rate),
    nn.Linear(model.fc.in_features, num_classes)
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.005) 
    criterion = nn.CrossEntropyLoss()

    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step(val_loss)
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'c2_best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as c2_best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 2.9014, Train Acc: 42.50%, Val Loss: 130405885952.0000, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 3.9464, Train Acc: 40.00%, Val Loss: 10124920.2500, Val Acc: 40.00%
# Starting epoch 3
# Train Loss: 2.6975, Train Acc: 47.50%, Val Loss: 1519.6082, Val Acc: 60.00%
# Starting epoch 4
# Train Loss: 1.5812, Train Acc: 47.50%, Val Loss: 65.8495, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 2.5038, Train Acc: 50.00%, Val Loss: 2.0231, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 2.1644, Train Acc: 47.50%, Val Loss: 92.0256, Val Acc: 60.00%
# Starting epoch 7
# Train Loss: 2.7140, Train Acc: 45.00%, Val Loss: 6.2575, Val Acc: 40.00%
# Starting epoch 8
# Train Loss: 1.8510, Train Acc: 52.50%, Val Loss: 2.1040, Val Acc: 40.00%
# Epoch 00008: reducing learning rate of group 0 to 1.0000e-03.
# Starting epoch 9
# Train Loss: 2.2012, Train Acc: 60.00%, Val Loss: 1.3625, Val Acc: 60.00%
# Starting epoch 10
# Train Loss: 0.8323, Train Acc: 60.00%, Val Loss: 1.4945, Val Acc: 50.00%
# Starting epoch 11
# Train Loss: 2.2809, Train Acc: 42.50%, Val Loss: 0.9705, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 1.6066, Train Acc: 55.00%, Val Loss: 0.7296, Val Acc: 40.00%
# Starting epoch 13
# Train Loss: 1.7042, Train Acc: 55.00%, Val Loss: 0.5144, Val Acc: 90.00%
# Starting epoch 14
# Train Loss: 1.1210, Train Acc: 62.50%, Val Loss: 0.3879, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 1.5589, Train Acc: 52.50%, Val Loss: 0.3330, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.6675, Train Acc: 62.50%, Val Loss: 0.4993, Val Acc: 70.00%
# Starting epoch 17
# Train Loss: 1.0727, Train Acc: 62.50%, Val Loss: 0.4708, Val Acc: 80.00%
# Starting epoch 18
# Train Loss: 0.7721, Train Acc: 67.50%, Val Loss: 0.5887, Val Acc: 80.00%
# Epoch 00018: reducing learning rate of group 0 to 1.0000e-04.
# Starting epoch 19
# Train Loss: 1.4515, Train Acc: 47.50%, Val Loss: 0.5679, Val Acc: 80.00%
# Starting epoch 20
# Train Loss: 1.5589, Train Acc: 62.50%, Val Loss: 0.5312, Val Acc: 80.00%
# Starting epoch 21
# Train Loss: 0.8873, Train Acc: 62.50%, Val Loss: 0.5097, Val Acc: 80.00%
# Epoch 00021: reducing learning rate of group 0 to 1.0000e-05.
# Starting epoch 22
# Train Loss: 1.2960, Train Acc: 70.00%, Val Loss: 0.5109, Val Acc: 80.00%
# Starting epoch 23
# Train Loss: 0.7926, Train Acc: 67.50%, Val Loss: 0.5236, Val Acc: 80.00%
# Starting epoch 24
# Train Loss: 1.4363, Train Acc: 60.00%, Val Loss: 0.5110, Val Acc: 80.00%
# Epoch 00024: reducing learning rate of group 0 to 1.0000e-06.
# Starting epoch 25
# Train Loss: 1.2170, Train Acc: 62.50%, Val Loss: 0.5112, Val Acc: 80.00%
# Starting epoch 26
# Train Loss: 0.9846, Train Acc: 55.00%, Val Loss: 0.5165, Val Acc: 80.00%
# Starting epoch 27
# Train Loss: 1.5178, Train Acc: 47.50%, Val Loss: 0.5098, Val Acc: 80.00%
# Epoch 00027: reducing learning rate of group 0 to 1.0000e-07.
# Starting epoch 28
# Train Loss: 1.1473, Train Acc: 72.50%, Val Loss: 0.5078, Val Acc: 80.00%
# Starting epoch 29
# Train Loss: 1.3676, Train Acc: 55.00%, Val Loss: 0.5341, Val Acc: 80.00%
# Starting epoch 30
# Train Loss: 1.0745, Train Acc: 60.00%, Val Loss: 0.5451, Val Acc: 80.00%
# Epoch 00030: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 31
# Train Loss: 1.3128, Train Acc: 52.50%, Val Loss: 0.5136, Val Acc: 80.00%
# Starting epoch 32
# Train Loss: 1.7498, Train Acc: 57.50%, Val Loss: 0.5333, Val Acc: 80.00%
# Starting epoch 33
# Train Loss: 1.0209, Train Acc: 57.50%, Val Loss: 0.5119, Val Acc: 80.00%
# Starting epoch 34
# Train Loss: 1.1512, Train Acc: 50.00%, Val Loss: 0.5074, Val Acc: 80.00%
# Starting epoch 35
# Train Loss: 1.3568, Train Acc: 55.00%, Val Loss: 0.5099, Val Acc: 80.00%
# Starting epoch 36
# Train Loss: 1.1558, Train Acc: 67.50%, Val Loss: 0.5219, Val Acc: 80.00%
# Starting epoch 37
# Train Loss: 1.2960, Train Acc: 50.00%, Val Loss: 0.5576, Val Acc: 80.00%
# Starting epoch 38
# Train Loss: 0.8222, Train Acc: 60.00%, Val Loss: 0.5211, Val Acc: 80.00%
# Starting epoch 39
# Train Loss: 1.2322, Train Acc: 57.50%, Val Loss: 0.5267, Val Acc: 80.00%
# Starting epoch 40
# Train Loss: 1.0657, Train Acc: 60.00%, Val Loss: 0.5404, Val Acc: 80.00%
# Early stopping triggered.
# --------------------------------
# FOLD 1
# --------------------------------
# Starting epoch 1
# Train Loss: 2.8160, Train Acc: 50.00%, Val Loss: 0.6318, Val Acc: 50.00%
# Starting epoch 2
# Train Loss: 2.0006, Train Acc: 45.00%, Val Loss: 0.8673, Val Acc: 60.00%
# Starting epoch 3
# Train Loss: 1.7541, Train Acc: 55.00%, Val Loss: 1.1534, Val Acc: 40.00%
# Starting epoch 4
# Epoch 00026: reducing learning rate of group 0 to 1.0000e-07.
# Starting epoch 27
# Train Loss: 1.5903, Train Acc: 42.50%, Val Loss: 0.8565, Val Acc: 70.00%
# Starting epoch 28
# Train Loss: 1.1759, Train Acc: 55.00%, Val Loss: 0.9084, Val Acc: 60.00%
# Starting epoch 29
# Train Loss: 1.0511, Train Acc: 55.00%, Val Loss: 0.9665, Val Acc: 70.00%
# Epoch 00029: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 30
# Train Loss: 1.7245, Train Acc: 55.00%, Val Loss: 1.2043, Val Acc: 50.00%
# Starting epoch 31
# Train Loss: 1.1505, Train Acc: 50.00%, Val Loss: 0.9962, Val Acc: 70.00%
# Starting epoch 32
# Train Loss: 1.3231, Train Acc: 55.00%, Val Loss: 0.8972, Val Acc: 60.00%
# Starting epoch 33
# Train Loss: 1.1802, Train Acc: 47.50%, Val Loss: 0.8848, Val Acc: 60.00%
# Starting epoch 34
# Train Loss: 1.5240, Train Acc: 40.00%, Val Loss: 0.9305, Val Acc: 60.00%
# Starting epoch 35
# Train Loss: 1.2758, Train Acc: 57.50%, Val Loss: 0.9033, Val Acc: 70.00%
# Starting epoch 36
# Train Loss: 1.2900, Train Acc: 47.50%, Val Loss: 0.8804, Val Acc: 60.00%
# Starting epoch 37
# Train Loss: 1.3528, Train Acc: 57.50%, Val Loss: 0.8019, Val Acc: 60.00%
# Starting epoch 38
# Train Loss: 1.4055, Train Acc: 40.00%, Val Loss: 0.8492, Val Acc: 60.00%
# Starting epoch 39
# Train Loss: 0.7879, Train Acc: 57.50%, Val Loss: 0.8588, Val Acc: 60.00%
# Starting epoch 40
# Train Loss: 1.3006, Train Acc: 47.50%, Val Loss: 0.9412, Val Acc: 70.00%
# Starting epoch 41
# Train Loss: 1.4732, Train Acc: 40.00%, Val Loss: 0.8963, Val Acc: 70.00%
# Starting epoch 42
# Train Loss: 1.5266, Train Acc: 37.50%, Val Loss: 0.8835, Val Acc: 70.00%
# Starting epoch 43
# Train Loss: 1.6194, Train Acc: 45.00%, Val Loss: 0.8388, Val Acc: 70.00%
# Starting epoch 44
# Train Loss: 1.2899, Train Acc: 47.50%, Val Loss: 0.7810, Val Acc: 70.00%
# Starting epoch 45
# Train Loss: 1.1568, Train Acc: 52.50%, Val Loss: 0.9813, Val Acc: 60.00%
# Early stopping triggered.
# --------------------------------
# FOLD 3
# --------------------------------
# Starting epoch 1
# Train Loss: 1.8878, Train Acc: 50.00%, Val Loss: 1.1230, Val Acc: 60.00%
# Starting epoch 2
# Train Loss: 2.1258, Train Acc: 60.00%, Val Loss: 0.7889, Val Acc: 70.00%
# Starting epoch 3
# Train Loss: 2.4524, Train Acc: 52.50%, Val Loss: 0.8179, Val Acc: 70.00%
# Starting epoch 4
# Train Loss: 1.4474, Train Acc: 57.50%, Val Loss: 2.5188, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 2.0898, Train Acc: 62.50%, Val Loss: 0.8810, Val Acc: 40.00%
# Epoch 00005: reducing learning rate of group 0 to 1.0000e-03.
# Starting epoch 6
# Train Loss: 1.3521, Train Acc: 57.50%, Val Loss: 0.6692, Val Acc: 70.00%
# Starting epoch 7
# Train Loss: 1.2928, Train Acc: 47.50%, Val Loss: 0.7956, Val Acc: 50.00%
# Starting epoch 8
# Train Loss: 1.3136, Train Acc: 57.50%, Val Loss: 0.7854, Val Acc: 70.00%
# Starting epoch 9
# Train Loss: 1.5217, Train Acc: 47.50%, Val Loss: 0.7231, Val Acc: 60.00%
# Epoch 00009: reducing learning rate of group 0 to 1.0000e-04.
# Starting epoch 10
# Train Loss: 1.6128, Train Acc: 32.50%, Val Loss: 0.9678, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 1.6303, Train Acc: 40.00%, Val Loss: 1.3708, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 1.2317, Train Acc: 57.50%, Val Loss: 1.4653, Val Acc: 50.00%
# Epoch 00012: reducing learning rate of group 0 to 1.0000e-05.
# Starting epoch 13
# Train Loss: 0.8108, Train Acc: 65.00%, Val Loss: 1.5327, Val Acc: 40.00%
# Starting epoch 14
# Train Loss: 1.0769, Train Acc: 57.50%, Val Loss: 1.3599, Val Acc: 50.00%
# Starting epoch 15
# Train Loss: 1.4336, Train Acc: 42.50%, Val Loss: 1.2509, Val Acc: 60.00%
# Epoch 00015: reducing learning rate of group 0 to 1.0000e-06.
# Starting epoch 16
# Train Loss: 1.0731, Train Acc: 70.00%, Val Loss: 2.2050, Val Acc: 60.00%
# Starting epoch 17
# Train Loss: 1.1685, Train Acc: 50.00%, Val Loss: 1.8455, Val Acc: 50.00%
# Starting epoch 18
# Train Loss: 1.1274, Train Acc: 60.00%, Val Loss: 1.9449, Val Acc: 30.00%
# Epoch 00018: reducing learning rate of group 0 to 1.0000e-07.
# Starting epoch 19
# Train Loss: 1.1028, Train Acc: 57.50%, Val Loss: 1.4577, Val Acc: 50.00%
# Starting epoch 20
# Train Loss: 1.5481, Train Acc: 37.50%, Val Loss: 1.5513, Val Acc: 30.00%
# Starting epoch 21
# Train Loss: 1.4331, Train Acc: 52.50%, Val Loss: 1.3359, Val Acc: 60.00%
# Epoch 00021: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 22
# Train Loss: 1.1921, Train Acc: 57.50%, Val Loss: 1.3261, Val Acc: 40.00%
# Starting epoch 23
# Train Loss: 1.9025, Train Acc: 42.50%, Val Loss: 1.4919, Val Acc: 30.00%
# Starting epoch 24
# Train Loss: 1.2059, Train Acc: 47.50%, Val Loss: 1.7933, Val Acc: 40.00%
# Starting epoch 25
# Train Loss: 1.5023, Train Acc: 52.50%, Val Loss: 1.9436, Val Acc: 30.00%
# Starting epoch 26
# Train Loss: 1.1257, Train Acc: 57.50%, Val Loss: 1.6238, Val Acc: 30.00%
# Starting epoch 27
# Train Loss: 1.8309, Train Acc: 50.00%, Val Loss: 1.9563, Val Acc: 30.00%
# Starting epoch 28
# Train Loss: 1.2645, Train Acc: 60.00%, Val Loss: 1.2391, Val Acc: 50.00%
# Starting epoch 29
# Train Loss: 1.3899, Train Acc: 50.00%, Val Loss: 1.1970, Val Acc: 50.00%
# Starting epoch 30
# Train Loss: 0.7767, Train Acc: 65.00%, Val Loss: 0.8238, Val Acc: 50.00%
# Starting epoch 31
# Train Loss: 1.1853, Train Acc: 57.50%, Val Loss: 0.9482, Val Acc: 50.00%
# Early stopping triggered.
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 2.7377, Train Acc: 47.50%, Val Loss: 0.9135, Val Acc: 70.00%
# Starting epoch 2
# Train Loss: 2.5859, Train Acc: 42.50%, Val Loss: 0.5844, Val Acc: 80.00%
# Starting epoch 3
# Train Loss: 2.1426, Train Acc: 40.00%, Val Loss: 325.5606, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 2.2254, Train Acc: 52.50%, Val Loss: 12.0125, Val Acc: 30.00%
# Starting epoch 5
# Train Loss: 1.8184, Train Acc: 37.50%, Val Loss: 0.7762, Val Acc: 60.00%
# Epoch 00005: reducing learning rate of group 0 to 1.0000e-03.
# Starting epoch 6
# Train Loss: 1.1442, Train Acc: 65.00%, Val Loss: 0.6462, Val Acc: 60.00%
# Starting epoch 7
# Train Loss: 1.4519, Train Acc: 45.00%, Val Loss: 0.6138, Val Acc: 70.00%
# Starting epoch 8
# Train Loss: 1.1115, Train Acc: 60.00%, Val Loss: 0.6356, Val Acc: 50.00%
# Epoch 00008: reducing learning rate of group 0 to 1.0000e-04.
# Starting epoch 9
# Train Loss: 1.0829, Train Acc: 62.50%, Val Loss: 0.5640, Val Acc: 60.00%
# Starting epoch 10
# Train Loss: 1.2902, Train Acc: 57.50%, Val Loss: 0.5234, Val Acc: 70.00%
# Starting epoch 11
# Train Loss: 0.7846, Train Acc: 60.00%, Val Loss: 0.5206, Val Acc: 70.00%
# Starting epoch 12
# Train Loss: 1.0390, Train Acc: 65.00%, Val Loss: 0.5333, Val Acc: 70.00%
# Starting epoch 13
# Train Loss: 1.3968, Train Acc: 55.00%, Val Loss: 0.5315, Val Acc: 70.00%
# Starting epoch 14
# Train Loss: 1.6819, Train Acc: 52.50%, Val Loss: 0.5898, Val Acc: 60.00%
# Epoch 00014: reducing learning rate of group 0 to 1.0000e-05.
# Starting epoch 15
# Train Loss: 0.9982, Train Acc: 60.00%, Val Loss: 0.6801, Val Acc: 60.00%
# Starting epoch 16
# Train Loss: 0.9774, Train Acc: 52.50%, Val Loss: 0.5787, Val Acc: 60.00%
# Starting epoch 17
# Train Loss: 1.0509, Train Acc: 70.00%, Val Loss: 0.5756, Val Acc: 60.00%
# Epoch 00017: reducing learning rate of group 0 to 1.0000e-06.
# Starting epoch 18
# Train Loss: 1.0892, Train Acc: 65.00%, Val Loss: 0.6065, Val Acc: 60.00%
# Starting epoch 19
# Train Loss: 1.0262, Train Acc: 52.50%, Val Loss: 0.6052, Val Acc: 60.00%
# Starting epoch 20
# Train Loss: 1.6912, Train Acc: 55.00%, Val Loss: 0.5497, Val Acc: 60.00%
# Epoch 00020: reducing learning rate of group 0 to 1.0000e-07.
# Starting epoch 21
# Train Loss: 1.0878, Train Acc: 62.50%, Val Loss: 0.5487, Val Acc: 70.00%
# Starting epoch 22
# Train Loss: 1.6395, Train Acc: 50.00%, Val Loss: 0.5764, Val Acc: 60.00%
# Starting epoch 23
# Train Loss: 0.5769, Train Acc: 77.50%, Val Loss: 0.5828, Val Acc: 60.00%
# Epoch 00023: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 24
# Train Loss: 1.6423, Train Acc: 47.50%, Val Loss: 0.5768, Val Acc: 60.00%
# Starting epoch 25
# Train Loss: 1.3589, Train Acc: 47.50%, Val Loss: 0.5962, Val Acc: 60.00%
# Starting epoch 26
# Train Loss: 0.8732, Train Acc: 52.50%, Val Loss: 0.5329, Val Acc: 70.00%
# Starting epoch 27
# Train Loss: 0.8261, Train Acc: 57.50%, Val Loss: 0.5733, Val Acc: 60.00%
# Starting epoch 28
# Train Loss: 1.3424, Train Acc: 45.00%, Val Loss: 0.5737, Val Acc: 60.00%
# Starting epoch 29
# Train Loss: 1.2053, Train Acc: 57.50%, Val Loss: 0.5445, Val Acc: 70.00%
# Starting epoch 30
# Train Loss: 1.3569, Train Acc: 62.50%, Val Loss: 0.6045, Val Acc: 60.00%
# Starting epoch 31
# Train Loss: 0.9414, Train Acc: 70.00%, Val Loss: 0.5497, Val Acc: 70.00%
# Starting epoch 32
# Train Loss: 2.1650, Train Acc: 52.50%, Val Loss: 0.5428, Val Acc: 70.00%
# Starting epoch 33
# Train Loss: 1.1518, Train Acc: 50.00%, Val Loss: 0.5366, Val Acc: 70.00%
# Starting epoch 34
# Train Loss: 0.8733, Train Acc: 62.50%, Val Loss: 0.5321, Val Acc: 70.00%
# Starting epoch 35
# Train Loss: 1.9314, Train Acc: 52.50%, Val Loss: 0.5278, Val Acc: 70.00%
# Starting epoch 36
# Train Loss: 0.7343, Train Acc: 72.50%, Val Loss: 0.5406, Val Acc: 70.00%
# Early stopping triggered.
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as c2_best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('c2_best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 1.0636, Test Accuracy: 59.40%
