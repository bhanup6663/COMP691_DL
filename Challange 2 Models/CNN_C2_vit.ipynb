# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset,DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [7 9]

# %%
model = models.vit_b_16(pretrained=True)

num_classes = 10
dropout_rate = 0.5 

model.heads = nn.Sequential(
    nn.Dropout(p=dropout_rate),  
    nn.Linear(model.heads[0].in_features, num_classes)
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=2e-5, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-5)
    criterion = nn.CrossEntropyLoss()

    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step()
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'c2_best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as c2_best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 1.7833, Train Acc: 42.50%, Val Loss: 0.9103, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.5530, Train Acc: 90.00%, Val Loss: 0.3101, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.2313, Train Acc: 95.00%, Val Loss: 0.2122, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.1644, Train Acc: 97.50%, Val Loss: 0.1252, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0898, Train Acc: 100.00%, Val Loss: 0.0841, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0416, Train Acc: 100.00%, Val Loss: 0.0652, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0311, Train Acc: 100.00%, Val Loss: 0.0541, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0237, Train Acc: 100.00%, Val Loss: 0.0431, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0178, Train Acc: 100.00%, Val Loss: 0.0364, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0147, Train Acc: 100.00%, Val Loss: 0.0324, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0119, Train Acc: 100.00%, Val Loss: 0.0309, Val Acc: 100.00%
# Starting epoch 12
# Train Loss: 0.0105, Train Acc: 100.00%, Val Loss: 0.0296, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0093, Train Acc: 100.00%, Val Loss: 0.0285, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0099, Train Acc: 100.00%, Val Loss: 0.0275, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0096, Train Acc: 100.00%, Val Loss: 0.0266, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0086, Train Acc: 100.00%, Val Loss: 0.0260, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0079, Train Acc: 100.00%, Val Loss: 0.0248, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0094, Train Acc: 100.00%, Val Loss: 0.0235, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0068, Train Acc: 100.00%, Val Loss: 0.0224, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0066, Train Acc: 100.00%, Val Loss: 0.0216, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0068, Train Acc: 100.00%, Val Loss: 0.0212, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0065, Train Acc: 100.00%, Val Loss: 0.0208, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0069, Train Acc: 100.00%, Val Loss: 0.0204, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0074, Train Acc: 100.00%, Val Loss: 0.0200, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0196, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.0193, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0054, Train Acc: 100.00%, Val Loss: 0.0190, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0056, Train Acc: 100.00%, Val Loss: 0.0186, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.0183, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0050, Train Acc: 100.00%, Val Loss: 0.0180, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0178, Val Acc: 100.00%
# Starting epoch 32
# Train Loss: 0.0049, Train Acc: 100.00%, Val Loss: 0.0177, Val Acc: 100.00%
# Starting epoch 33
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0175, Val Acc: 100.00%
# Starting epoch 34
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.0174, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.0043, Train Acc: 100.00%, Val Loss: 0.0173, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.0172, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.0170, Val Acc: 100.00%
# Starting epoch 38
# Train Loss: 0.0046, Train Acc: 100.00%, Val Loss: 0.0169, Val Acc: 100.00%
# Starting epoch 39
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.0168, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0054, Train Acc: 100.00%, Val Loss: 0.0166, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.0049, Train Acc: 100.00%, Val Loss: 0.0166, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0039, Train Acc: 100.00%, Val Loss: 0.0165, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0045, Train Acc: 100.00%, Val Loss: 0.0164, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0163, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0163, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0045, Train Acc: 100.00%, Val Loss: 0.0162, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.0161, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0037, Train Acc: 100.00%, Val Loss: 0.0161, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0160, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0159, Val Acc: 100.00%
# --------------------------------
# FOLD 1
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0029, Train Acc: 100.00%, Val Loss: 0.0072, Val Acc: 100.00%
# Starting epoch 2
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.0081, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0191, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.0108, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0136, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0173, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0062, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0052, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0086, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0190, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0295, Val Acc: 100.00%
# Starting epoch 12
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0416, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0468, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0420, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0401, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0480, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0560, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0613, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0589, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0449, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0451, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0494, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0573, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0653, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0671, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0684, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0704, Val Acc: 90.00%
# Starting epoch 28
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0758, Val Acc: 90.00%
# Starting epoch 29
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0832, Val Acc: 90.00%
# Starting epoch 30
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0864, Val Acc: 90.00%
# Starting epoch 31
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0878, Val Acc: 90.00%
# Starting epoch 32
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0988, Val Acc: 90.00%
# Starting epoch 33
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.1126, Val Acc: 90.00%
# Early stopping triggered.
# --------------------------------
# FOLD 2
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.3936, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2227, Val Acc: 90.00%
# Starting epoch 3
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.5223, Val Acc: 90.00%
# Starting epoch 4
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.5248, Val Acc: 90.00%
# Starting epoch 5
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.2410, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9198, Val Acc: 90.00%
# Starting epoch 7
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.5781, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.6071, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.7383, Val Acc: 90.00%
# Starting epoch 10
# Train Loss: 0.0322, Train Acc: 97.50%, Val Loss: 0.3436, Val Acc: 90.00%
# Starting epoch 11
# Train Loss: 0.0011, Train Acc: 100.00%, Val Loss: 1.0403, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0096, Train Acc: 100.00%, Val Loss: 0.7249, Val Acc: 90.00%
# Starting epoch 13
# Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.4389, Val Acc: 90.00%
# Starting epoch 14
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.3092, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2557, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2342, Val Acc: 90.00%
# Starting epoch 17
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2263, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2244, Val Acc: 90.00%
# Starting epoch 19
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2248, Val Acc: 90.00%
# Starting epoch 20
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2265, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2280, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2295, Val Acc: 90.00%
# Starting epoch 23
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2307, Val Acc: 90.00%
# Starting epoch 24
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2320, Val Acc: 90.00%
# Starting epoch 25
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2333, Val Acc: 90.00%
# Starting epoch 26
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2346, Val Acc: 90.00%
# Starting epoch 27
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.2361, Val Acc: 90.00%
# Early stopping triggered.
# --------------------------------
# FOLD 3
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.8780, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0707, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.8833, Val Acc: 90.00%
# Starting epoch 4
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 1.0729, Val Acc: 90.00%
# Starting epoch 5
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 1.1126, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9877, Val Acc: 90.00%
# Starting epoch 7
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.8098, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.7026, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.6499, Val Acc: 90.00%
# Starting epoch 10
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.6979, Val Acc: 90.00%
# Starting epoch 11
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.7282, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.7719, Val Acc: 90.00%
# Starting epoch 13
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.8970, Val Acc: 90.00%
# Starting epoch 14
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9379, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9271, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9195, Val Acc: 90.00%
# Starting epoch 17
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9183, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.9109, Val Acc: 90.00%
# Starting epoch 19
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 1.5805, Val Acc: 70.00%
# Starting epoch 20
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 1.3500, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.1538, Train Acc: 95.00%, Val Loss: 2.2551, Val Acc: 70.00%
# Starting epoch 22
# Train Loss: 0.1424, Train Acc: 97.50%, Val Loss: 4.3149, Val Acc: 50.00%
# Starting epoch 23
# Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 3.1789, Val Acc: 70.00%
# Starting epoch 24
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 3.0296, Val Acc: 60.00%
# Starting epoch 25
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 2.9910, Val Acc: 60.00%
# Starting epoch 26
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 2.9748, Val Acc: 60.00%
# Starting epoch 27
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 2.9696, Val Acc: 60.00%
# Early stopping triggered.
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0313, Train Acc: 97.50%, Val Loss: 1.0281, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.2060, Val Acc: 60.00%
# Starting epoch 3
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 6.7790, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 0.0288, Train Acc: 97.50%, Val Loss: 0.4408, Val Acc: 90.00%
# Starting epoch 5
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.8002, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0409, Train Acc: 97.50%, Val Loss: 0.0168, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.2527, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 1.0337, Val Acc: 60.00%
# Starting epoch 9
# Train Loss: 0.0014, Train Acc: 100.00%, Val Loss: 1.4965, Val Acc: 50.00%
# Starting epoch 10
# Train Loss: 0.0037, Train Acc: 100.00%, Val Loss: 0.9232, Val Acc: 60.00%
# Starting epoch 11
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.1120, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0101, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0048, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0040, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0038, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0037, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0037, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0037, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0036, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 32
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 33
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 34
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 38
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 39
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0035, Val Acc: 100.00%
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as c2_best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('c2_best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 0.1201, Test Accuracy: 97.75%
