# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset,DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [5 3]

# %%
model = models.resnet50(pretrained=True)

num_classes = 10  
dropout_rate = 0.5  

# Modify the fully connected layer
model.fc = nn.Sequential(
    nn.Dropout(dropout_rate),
    nn.Linear(model.fc.in_features, num_classes)
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.005) 
    criterion = nn.CrossEntropyLoss()

    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step(val_loss)
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'c2_best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as c2_best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 2.7609, Train Acc: 40.00%, Val Loss: 10246793728.0000, Val Acc: 60.00%
# Starting epoch 2
# Train Loss: 3.5117, Train Acc: 55.00%, Val Loss: 125176212.0000, Val Acc: 40.00%
# Starting epoch 3
# Train Loss: 5.0752, Train Acc: 40.00%, Val Loss: 194479.7695, Val Acc: 60.00%
# Starting epoch 4
# Train Loss: 5.1973, Train Acc: 47.50%, Val Loss: 165.3736, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 3.1304, Train Acc: 45.00%, Val Loss: 275.5327, Val Acc: 50.00%
# Starting epoch 6
# Train Loss: 1.8118, Train Acc: 60.00%, Val Loss: 490.2491, Val Acc: 50.00%
# Starting epoch 7
# Train Loss: 2.2216, Train Acc: 60.00%, Val Loss: 18.3803, Val Acc: 40.00%
# Starting epoch 8
# Train Loss: 1.2724, Train Acc: 42.50%, Val Loss: 1.2064, Val Acc: 60.00%
# Starting epoch 9
# Train Loss: 2.1346, Train Acc: 42.50%, Val Loss: 0.8018, Val Acc: 60.00%
# Starting epoch 10
# Train Loss: 1.7633, Train Acc: 42.50%, Val Loss: 0.5644, Val Acc: 70.00%
# Starting epoch 11
# Train Loss: 3.3802, Train Acc: 42.50%, Val Loss: 0.5521, Val Acc: 80.00%
# Starting epoch 12
# Train Loss: 1.9580, Train Acc: 45.00%, Val Loss: 0.6227, Val Acc: 50.00%
# Starting epoch 13
# Train Loss: 1.9214, Train Acc: 35.00%, Val Loss: 1.1370, Val Acc: 40.00%
# Starting epoch 14
# Train Loss: 1.2214, Train Acc: 65.00%, Val Loss: 0.6231, Val Acc: 60.00%
# Epoch 00014: reducing learning rate of group 0 to 1.0000e-03.
# Starting epoch 15
# Train Loss: 1.0552, Train Acc: 67.50%, Val Loss: 0.7382, Val Acc: 60.00%
# Starting epoch 16
# Train Loss: 2.0968, Train Acc: 42.50%, Val Loss: 0.6726, Val Acc: 60.00%
# Starting epoch 17
# Train Loss: 0.9262, Train Acc: 60.00%, Val Loss: 0.6670, Val Acc: 70.00%
# Epoch 00017: reducing learning rate of group 0 to 1.0000e-04.
# Starting epoch 18
# Train Loss: 0.9327, Train Acc: 62.50%, Val Loss: 0.5962, Val Acc: 70.00%
# Starting epoch 19
# Train Loss: 1.1189, Train Acc: 62.50%, Val Loss: 0.6211, Val Acc: 70.00%
# Starting epoch 20
# Train Loss: 1.2316, Train Acc: 65.00%, Val Loss: 0.6893, Val Acc: 70.00%
# Epoch 00020: reducing learning rate of group 0 to 1.0000e-05.
# Starting epoch 21
# Train Loss: 1.2536, Train Acc: 47.50%, Val Loss: 0.6632, Val Acc: 70.00%
# Epoch 00035: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 36
# Train Loss: 1.5670, Train Acc: 35.00%, Val Loss: 0.6770, Val Acc: 70.00%
# Starting epoch 37
# Train Loss: 1.1869, Train Acc: 55.00%, Val Loss: 0.6964, Val Acc: 50.00%
# Starting epoch 38
# Train Loss: 1.2981, Train Acc: 60.00%, Val Loss: 0.6852, Val Acc: 70.00%
# Starting epoch 39
# Train Loss: 1.3272, Train Acc: 65.00%, Val Loss: 0.6576, Val Acc: 60.00%
# Starting epoch 40
# Train Loss: 1.0748, Train Acc: 47.50%, Val Loss: 0.6439, Val Acc: 70.00%
# Starting epoch 41
# Train Loss: 1.5371, Train Acc: 55.00%, Val Loss: 0.6730, Val Acc: 70.00%
# Starting epoch 42
# Train Loss: 1.8552, Train Acc: 42.50%, Val Loss: 0.6504, Val Acc: 70.00%
# Starting epoch 43
# Train Loss: 1.0305, Train Acc: 57.50%, Val Loss: 0.6618, Val Acc: 70.00%
# Starting epoch 44
# Train Loss: 1.1942, Train Acc: 67.50%, Val Loss: 0.6859, Val Acc: 60.00%
# Starting epoch 45
# Train Loss: 0.9976, Train Acc: 50.00%, Val Loss: 0.6763, Val Acc: 70.00%
# Starting epoch 46
# Train Loss: 1.0586, Train Acc: 47.50%, Val Loss: 0.6968, Val Acc: 70.00%
# Starting epoch 47
# Train Loss: 1.0376, Train Acc: 45.00%, Val Loss: 0.7033, Val Acc: 60.00%
# Starting epoch 48
# Train Loss: 1.1238, Train Acc: 65.00%, Val Loss: 0.7307, Val Acc: 70.00%
# Early stopping triggered.
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 2.5976, Train Acc: 55.00%, Val Loss: 0.9974, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 2.0548, Train Acc: 52.50%, Val Loss: 1.6759, Val Acc: 40.00%
# Starting epoch 3
# Train Loss: 1.9675, Train Acc: 40.00%, Val Loss: 1.6456, Val Acc: 60.00%
# Starting epoch 4
# Train Loss: 1.5625, Train Acc: 60.00%, Val Loss: 1.3942, Val Acc: 20.00%
# Epoch 00004: reducing learning rate of group 0 to 1.0000e-03.
# Starting epoch 5
# Train Loss: 1.8668, Train Acc: 42.50%, Val Loss: 1.1268, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 1.2812, Train Acc: 47.50%, Val Loss: 0.8302, Val Acc: 60.00%
# Starting epoch 7
# Train Loss: 1.4324, Train Acc: 40.00%, Val Loss: 0.8393, Val Acc: 40.00%
# Starting epoch 8
# Train Loss: 1.2837, Train Acc: 62.50%, Val Loss: 1.0968, Val Acc: 40.00%
# Starting epoch 9
# Train Loss: 1.6308, Train Acc: 47.50%, Val Loss: 1.0234, Val Acc: 40.00%
# Epoch 00009: reducing learning rate of group 0 to 1.0000e-04.
# Starting epoch 10
# Train Loss: 1.2350, Train Acc: 47.50%, Val Loss: 0.8748, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 1.3370, Train Acc: 45.00%, Val Loss: 0.8279, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 0.9754, Train Acc: 57.50%, Val Loss: 0.7862, Val Acc: 40.00%
# Starting epoch 13
# Train Loss: 1.4508, Train Acc: 55.00%, Val Loss: 0.7609, Val Acc: 30.00%
# Starting epoch 14
# Train Loss: 1.7397, Train Acc: 50.00%, Val Loss: 0.7326, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 1.4435, Train Acc: 32.50%, Val Loss: 0.7453, Val Acc: 30.00%
# Starting epoch 16
# Train Loss: 0.9371, Train Acc: 52.50%, Val Loss: 0.7359, Val Acc: 30.00%
# Starting epoch 17
# Train Loss: 1.3727, Train Acc: 47.50%, Val Loss: 0.7683, Val Acc: 40.00%
# Epoch 00017: reducing learning rate of group 0 to 1.0000e-05.
# Starting epoch 18
# Train Loss: 1.0608, Train Acc: 60.00%, Val Loss: 0.7763, Val Acc: 40.00%
# Starting epoch 19
# Train Loss: 1.2750, Train Acc: 42.50%, Val Loss: 0.8046, Val Acc: 50.00%
# Starting epoch 20
# Train Loss: 0.9978, Train Acc: 55.00%, Val Loss: 0.8072, Val Acc: 50.00%
# Epoch 00020: reducing learning rate of group 0 to 1.0000e-06.
# Starting epoch 21
# Train Loss: 1.5881, Train Acc: 52.50%, Val Loss: 0.8502, Val Acc: 40.00%
# Starting epoch 22
# Train Loss: 1.5124, Train Acc: 50.00%, Val Loss: 0.8273, Val Acc: 40.00%
# Starting epoch 23
# Train Loss: 0.9820, Train Acc: 60.00%, Val Loss: 0.7235, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 1.3156, Train Acc: 52.50%, Val Loss: 0.7128, Val Acc: 40.00%
# Starting epoch 25
# Train Loss: 1.4591, Train Acc: 40.00%, Val Loss: 0.7592, Val Acc: 40.00%
# Starting epoch 26
# Train Loss: 1.2785, Train Acc: 57.50%, Val Loss: 0.8656, Val Acc: 40.00%
# Starting epoch 27
# Train Loss: 1.4911, Train Acc: 42.50%, Val Loss: 0.9121, Val Acc: 30.00%
# Epoch 00027: reducing learning rate of group 0 to 1.0000e-07.
# Starting epoch 28
# Train Loss: 1.0153, Train Acc: 52.50%, Val Loss: 0.7916, Val Acc: 30.00%
# Starting epoch 29
# Train Loss: 1.3815, Train Acc: 40.00%, Val Loss: 0.8575, Val Acc: 40.00%
# Starting epoch 30
# Train Loss: 1.3523, Train Acc: 52.50%, Val Loss: 0.8141, Val Acc: 50.00%
# Epoch 00030: reducing learning rate of group 0 to 1.0000e-08.
# Starting epoch 31
# Train Loss: 1.1803, Train Acc: 45.00%, Val Loss: 0.8297, Val Acc: 40.00%
# Starting epoch 32
# Train Loss: 1.3956, Train Acc: 45.00%, Val Loss: 0.8436, Val Acc: 40.00%
# Starting epoch 33
# Train Loss: 1.1653, Train Acc: 45.00%, Val Loss: 0.8068, Val Acc: 40.00%
# Starting epoch 34
# Train Loss: 0.9023, Train Acc: 60.00%, Val Loss: 0.9210, Val Acc: 30.00%
# Starting epoch 35
# Train Loss: 1.0960, Train Acc: 65.00%, Val Loss: 0.8255, Val Acc: 40.00%
# Starting epoch 36
# Train Loss: 1.1957, Train Acc: 47.50%, Val Loss: 0.8295, Val Acc: 40.00%
# Starting epoch 37
# Train Loss: 1.0195, Train Acc: 57.50%, Val Loss: 0.9044, Val Acc: 40.00%
# Starting epoch 38
# Train Loss: 0.8994, Train Acc: 62.50%, Val Loss: 0.9981, Val Acc: 40.00%
# Starting epoch 39
# Train Loss: 1.3862, Train Acc: 50.00%, Val Loss: 0.9934, Val Acc: 40.00%
# Starting epoch 40
# Train Loss: 1.3790, Train Acc: 42.50%, Val Loss: 0.8817, Val Acc: 50.00%
# Starting epoch 41
# Train Loss: 1.5452, Train Acc: 42.50%, Val Loss: 1.0205, Val Acc: 40.00%
# Starting epoch 42
# Train Loss: 1.0301, Train Acc: 55.00%, Val Loss: 1.0157, Val Acc: 40.00%
# Starting epoch 43
# Train Loss: 0.8697, Train Acc: 65.00%, Val Loss: 1.0109, Val Acc: 40.00%
# Starting epoch 44
# Train Loss: 1.0521, Train Acc: 60.00%, Val Loss: 1.0145, Val Acc: 40.00%
# Starting epoch 45
# Train Loss: 1.4160, Train Acc: 40.00%, Val Loss: 0.8416, Val Acc: 40.00%
# Starting epoch 46
# Train Loss: 1.2898, Train Acc: 45.00%, Val Loss: 1.0210, Val Acc: 40.00%
# Starting epoch 47
# Train Loss: 1.4893, Train Acc: 55.00%, Val Loss: 1.0273, Val Acc: 40.00%
# Starting epoch 48
# Train Loss: 1.4853, Train Acc: 50.00%, Val Loss: 0.9345, Val Acc: 30.00%
# Starting epoch 49
# Train Loss: 1.0350, Train Acc: 55.00%, Val Loss: 0.8599, Val Acc: 40.00%
# Early stopping triggered.
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as c2_best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('c2_best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 0.8443, Test Accuracy: 47.80%
