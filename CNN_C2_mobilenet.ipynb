# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset,DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [3 8]

# %%
model = models.mobilenet_v2(pretrained=True)

num_classes = 10
dropout_rate = 0.5

model.classifier = nn.Sequential(
    nn.Dropout(p=dropout_rate), 
    nn.Linear(model.classifier[1].in_features, num_classes)  
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=2e-5, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-5)
    criterion = nn.CrossEntropyLoss()

    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step(val_loss)
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'c2_best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as c2_best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 2.4961, Train Acc: 7.50%, Val Loss: 2.3090, Val Acc: 0.00%
# Starting epoch 2
# Train Loss: 2.4081, Train Acc: 12.50%, Val Loss: 2.3104, Val Acc: 10.00%
# Starting epoch 3
# Train Loss: 2.2892, Train Acc: 15.00%, Val Loss: 2.1967, Val Acc: 30.00%
# Starting epoch 4
# Train Loss: 1.9979, Train Acc: 35.00%, Val Loss: 2.1608, Val Acc: 20.00%
# Starting epoch 5
# Train Loss: 1.8259, Train Acc: 37.50%, Val Loss: 2.1490, Val Acc: 20.00%
# Starting epoch 6
# Train Loss: 1.7360, Train Acc: 37.50%, Val Loss: 2.0493, Val Acc: 20.00%
# Starting epoch 7
# Train Loss: 1.9125, Train Acc: 22.50%, Val Loss: 2.0388, Val Acc: 20.00%
# Starting epoch 8
# Train Loss: 1.5936, Train Acc: 40.00%, Val Loss: 2.1729, Val Acc: 0.00%
# Starting epoch 9
# Train Loss: 1.7596, Train Acc: 37.50%, Val Loss: 2.0158, Val Acc: 20.00%
# Starting epoch 10
# Train Loss: 1.5873, Train Acc: 40.00%, Val Loss: 1.9606, Val Acc: 50.00%
# Starting epoch 11
# Train Loss: 1.5593, Train Acc: 52.50%, Val Loss: 1.9990, Val Acc: 30.00%
# Starting epoch 12
# Train Loss: 1.5292, Train Acc: 40.00%, Val Loss: 1.9082, Val Acc: 50.00%
# Starting epoch 13
# Train Loss: 1.5483, Train Acc: 52.50%, Val Loss: 1.8569, Val Acc: 50.00%
# Starting epoch 14
# Train Loss: 1.4415, Train Acc: 55.00%, Val Loss: 1.8227, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 1.2671, Train Acc: 60.00%, Val Loss: 1.7895, Val Acc: 40.00%
# Starting epoch 16
# Train Loss: 1.2659, Train Acc: 47.50%, Val Loss: 1.7662, Val Acc: 40.00%
# Starting epoch 17
# Train Loss: 1.4047, Train Acc: 50.00%, Val Loss: 1.6717, Val Acc: 30.00%
# Starting epoch 18
# Train Loss: 1.2174, Train Acc: 55.00%, Val Loss: 1.6908, Val Acc: 40.00%
# Starting epoch 19
# Train Loss: 1.1681, Train Acc: 65.00%, Val Loss: 1.6414, Val Acc: 50.00%
# Starting epoch 20
# Train Loss: 1.1898, Train Acc: 67.50%, Val Loss: 1.6971, Val Acc: 50.00%
# Starting epoch 21
# Train Loss: 1.2026, Train Acc: 62.50%, Val Loss: 1.6754, Val Acc: 40.00%
# Starting epoch 22
# Train Loss: 0.9414, Train Acc: 72.50%, Val Loss: 1.6994, Val Acc: 40.00%
# Epoch 00022: reducing learning rate of group 0 to 2.0000e-06.
# Starting epoch 23
# Train Loss: 1.0738, Train Acc: 62.50%, Val Loss: 1.7449, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 1.1128, Train Acc: 67.50%, Val Loss: 1.7018, Val Acc: 40.00%
# Starting epoch 25
# Train Loss: 1.0044, Train Acc: 62.50%, Val Loss: 1.6774, Val Acc: 40.00%
# Epoch 00025: reducing learning rate of group 0 to 2.0000e-07.
# Starting epoch 26
# Train Loss: 1.0596, Train Acc: 75.00%, Val Loss: 1.6813, Val Acc: 40.00%
# Starting epoch 27
# Train Loss: 1.1057, Train Acc: 55.00%, Val Loss: 1.6740, Val Acc: 40.00%
# Starting epoch 28
# Train Loss: 1.1004, Train Acc: 60.00%, Val Loss: 1.6743, Val Acc: 50.00%
# Epoch 00028: reducing learning rate of group 0 to 2.0000e-08.
# Starting epoch 29
# Train Loss: 1.0775, Train Acc: 57.50%, Val Loss: 1.6231, Val Acc: 40.00%
# Starting epoch 30
# Train Loss: 1.0301, Train Acc: 72.50%, Val Loss: 1.6184, Val Acc: 50.00%
# Starting epoch 31
# Train Loss: 1.0954, Train Acc: 60.00%, Val Loss: 1.7088, Val Acc: 30.00%
# Starting epoch 32
# Train Loss: 1.0699, Train Acc: 65.00%, Val Loss: 1.7219, Val Acc: 30.00%
# Starting epoch 33
# Train Loss: 0.9946, Train Acc: 62.50%, Val Loss: 1.7111, Val Acc: 40.00%
# Epoch 00033: reducing learning rate of group 0 to 2.0000e-09.
# Starting epoch 34
# Train Loss: 1.0739, Train Acc: 70.00%, Val Loss: 1.7637, Val Acc: 50.00%
# Starting epoch 35
# Train Loss: 1.0387, Train Acc: 62.50%, Val Loss: 1.7161, Val Acc: 50.00%
# Starting epoch 36
# Train Loss: 1.0135, Train Acc: 70.00%, Val Loss: 1.6769, Val Acc: 50.00%
# Starting epoch 37
# Train Loss: 1.0776, Train Acc: 65.00%, Val Loss: 1.7124, Val Acc: 40.00%
# Starting epoch 38
# Train Loss: 1.2058, Train Acc: 45.00%, Val Loss: 1.8462, Val Acc: 40.00%
# Starting epoch 39
# Train Loss: 1.0750, Train Acc: 62.50%, Val Loss: 1.7001, Val Acc: 40.00%
# Starting epoch 40
# Train Loss: 1.0505, Train Acc: 67.50%, Val Loss: 1.6889, Val Acc: 40.00%
# Starting epoch 41
# Train Loss: 1.0831, Train Acc: 65.00%, Val Loss: 1.6502, Val Acc: 40.00%
# Starting epoch 42
# Train Loss: 1.1041, Train Acc: 52.50%, Val Loss: 1.7154, Val Acc: 40.00%
# Starting epoch 43
# Train Loss: 0.9861, Train Acc: 67.50%, Val Loss: 1.6776, Val Acc: 40.00%
# Starting epoch 44
# Train Loss: 1.3160, Train Acc: 45.00%, Val Loss: 1.6457, Val Acc: 40.00%
# Starting epoch 45
# Train Loss: 0.9090, Train Acc: 77.50%, Val Loss: 1.6162, Val Acc: 40.00%
# Starting epoch 46
# Train Loss: 1.2274, Train Acc: 52.50%, Val Loss: 1.6563, Val Acc: 40.00%
# Starting epoch 47
# Train Loss: 1.0843, Train Acc: 62.50%, Val Loss: 1.7048, Val Acc: 30.00%
# Starting epoch 48
# Train Loss: 1.0179, Train Acc: 67.50%, Val Loss: 1.6881, Val Acc: 30.00%
# Starting epoch 49
# Train Loss: 1.0122, Train Acc: 65.00%, Val Loss: 1.6432, Val Acc: 40.00%
# Starting epoch 50
# Train Loss: 1.0748, Train Acc: 65.00%, Val Loss: 1.6671, Val Acc: 40.00%
# --------------------------------
# FOLD 1
# --------------------------------
# Starting epoch 1
# Train Loss: 1.0236, Train Acc: 67.50%, Val Loss: 1.6466, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 1.2140, Train Acc: 55.00%, Val Loss: 1.5932, Val Acc: 30.00%
# Starting epoch 3
# Train Loss: 1.0957, Train Acc: 57.50%, Val Loss: 1.5254, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 0.9999, Train Acc: 65.00%, Val Loss: 1.5703, Val Acc: 30.00%
# Starting epoch 5
# Train Loss: 0.9235, Train Acc: 67.50%, Val Loss: 1.5364, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 0.9706, Train Acc: 62.50%, Val Loss: 1.5742, Val Acc: 40.00%
# Epoch 00006: reducing learning rate of group 0 to 2.0000e-06.
# Starting epoch 7
# Train Loss: 0.9713, Train Acc: 60.00%, Val Loss: 1.5329, Val Acc: 40.00%
# Starting epoch 8
# Train Loss: 1.0361, Train Acc: 52.50%, Val Loss: 1.5478, Val Acc: 40.00%
# Starting epoch 9
# Train Loss: 1.0019, Train Acc: 60.00%, Val Loss: 1.5994, Val Acc: 40.00%
# Epoch 00009: reducing learning rate of group 0 to 2.0000e-07.
# Starting epoch 10
# Train Loss: 0.8719, Train Acc: 62.50%, Val Loss: 1.4673, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 0.9155, Train Acc: 65.00%, Val Loss: 1.5797, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 0.8961, Train Acc: 65.00%, Val Loss: 1.5705, Val Acc: 40.00%
# Starting epoch 13
# Train Loss: 0.7826, Train Acc: 75.00%, Val Loss: 1.5674, Val Acc: 40.00%
# Epoch 00013: reducing learning rate of group 0 to 2.0000e-08.
# Starting epoch 14
# Train Loss: 0.9342, Train Acc: 60.00%, Val Loss: 1.5010, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 0.9133, Train Acc: 60.00%, Val Loss: 1.4800, Val Acc: 40.00%
# Starting epoch 16
# Train Loss: 0.9484, Train Acc: 70.00%, Val Loss: 1.4795, Val Acc: 40.00%
# Epoch 00016: reducing learning rate of group 0 to 2.0000e-09.
# Starting epoch 17
# Train Loss: 0.8483, Train Acc: 60.00%, Val Loss: 1.4478, Val Acc: 40.00%
# Starting epoch 18
# Train Loss: 0.8557, Train Acc: 67.50%, Val Loss: 1.5613, Val Acc: 40.00%
# Starting epoch 19
# Train Loss: 1.0513, Train Acc: 57.50%, Val Loss: 1.5181, Val Acc: 40.00%
# Starting epoch 20
# Train Loss: 0.7961, Train Acc: 72.50%, Val Loss: 1.4750, Val Acc: 40.00%
# Starting epoch 21
# Train Loss: 1.0969, Train Acc: 52.50%, Val Loss: 1.5672, Val Acc: 50.00%
# Starting epoch 22
# Train Loss: 0.7994, Train Acc: 72.50%, Val Loss: 1.5243, Val Acc: 40.00%
# Starting epoch 23
# Train Loss: 0.9489, Train Acc: 65.00%, Val Loss: 1.5357, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 0.8448, Train Acc: 65.00%, Val Loss: 1.5416, Val Acc: 40.00%
# Starting epoch 25
# Train Loss: 1.0428, Train Acc: 60.00%, Val Loss: 1.5673, Val Acc: 40.00%
# Starting epoch 26
# Train Loss: 0.9869, Train Acc: 55.00%, Val Loss: 1.4710, Val Acc: 40.00%
# Starting epoch 27
# Train Loss: 0.9834, Train Acc: 57.50%, Val Loss: 1.5197, Val Acc: 40.00%
# Starting epoch 28
# Train Loss: 0.7403, Train Acc: 77.50%, Val Loss: 1.5047, Val Acc: 40.00%
# Starting epoch 29
# Train Loss: 1.0544, Train Acc: 60.00%, Val Loss: 1.5667, Val Acc: 40.00%
# Starting epoch 30
# Train Loss: 0.8538, Train Acc: 75.00%, Val Loss: 1.5196, Val Acc: 40.00%
# Starting epoch 31
# Train Loss: 0.9149, Train Acc: 60.00%, Val Loss: 1.5230, Val Acc: 40.00%
# Starting epoch 32
# Train Loss: 0.8992, Train Acc: 65.00%, Val Loss: 1.4895, Val Acc: 40.00%
# Starting epoch 33
# Train Loss: 1.1771, Train Acc: 45.00%, Val Loss: 1.5414, Val Acc: 40.00%
# Starting epoch 34
# Train Loss: 0.8438, Train Acc: 65.00%, Val Loss: 1.4932, Val Acc: 40.00%
# Starting epoch 35
# Train Loss: 0.7983, Train Acc: 67.50%, Val Loss: 1.5552, Val Acc: 40.00%
# Starting epoch 36
# Train Loss: 0.9919, Train Acc: 55.00%, Val Loss: 1.4909, Val Acc: 40.00%
# Starting epoch 37
# Train Loss: 0.9170, Train Acc: 67.50%, Val Loss: 1.5456, Val Acc: 40.00%
# Starting epoch 38
# Train Loss: 0.8835, Train Acc: 62.50%, Val Loss: 1.5587, Val Acc: 40.00%
# Starting epoch 39
# Train Loss: 0.8893, Train Acc: 57.50%, Val Loss: 1.5657, Val Acc: 30.00%
# Starting epoch 40
# Train Loss: 0.8241, Train Acc: 72.50%, Val Loss: 1.5538, Val Acc: 40.00%
# Starting epoch 41
# Train Loss: 1.0221, Train Acc: 50.00%, Val Loss: 1.5302, Val Acc: 50.00%
# Starting epoch 42
# Train Loss: 0.7819, Train Acc: 75.00%, Val Loss: 1.4911, Val Acc: 40.00%
# Early stopping triggered.
# --------------------------------
# FOLD 2
# --------------------------------
# Starting epoch 1
# Train Loss: 0.9512, Train Acc: 57.50%, Val Loss: 1.4231, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 0.7546, Train Acc: 80.00%, Val Loss: 1.4192, Val Acc: 40.00%
# Starting epoch 3
# Train Loss: 0.8692, Train Acc: 67.50%, Val Loss: 1.4349, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 0.8011, Train Acc: 62.50%, Val Loss: 1.3503, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 0.8330, Train Acc: 67.50%, Val Loss: 1.3948, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 0.7475, Train Acc: 77.50%, Val Loss: 1.3959, Val Acc: 40.00%
# Starting epoch 7
# Train Loss: 0.6826, Train Acc: 80.00%, Val Loss: 1.4492, Val Acc: 40.00%
# Epoch 00007: reducing learning rate of group 0 to 2.0000e-06.
# Starting epoch 8
# Train Loss: 0.7584, Train Acc: 65.00%, Val Loss: 1.3882, Val Acc: 40.00%
# Starting epoch 9
# Train Loss: 0.9659, Train Acc: 52.50%, Val Loss: 1.3076, Val Acc: 40.00%
# Starting epoch 10
# Train Loss: 0.8259, Train Acc: 65.00%, Val Loss: 1.2695, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 0.5831, Train Acc: 77.50%, Val Loss: 1.2758, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 0.7641, Train Acc: 67.50%, Val Loss: 1.3958, Val Acc: 30.00%
# Starting epoch 13
# Train Loss: 0.6546, Train Acc: 72.50%, Val Loss: 1.3479, Val Acc: 40.00%
# Epoch 00013: reducing learning rate of group 0 to 2.0000e-07.
# Starting epoch 14
# Train Loss: 0.7272, Train Acc: 60.00%, Val Loss: 1.3570, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 0.7780, Train Acc: 65.00%, Val Loss: 1.5090, Val Acc: 40.00%
# Starting epoch 16
# Train Loss: 0.6734, Train Acc: 75.00%, Val Loss: 1.3567, Val Acc: 40.00%
# Epoch 00016: reducing learning rate of group 0 to 2.0000e-08.
# Starting epoch 17
# Train Loss: 0.8600, Train Acc: 55.00%, Val Loss: 1.3291, Val Acc: 40.00%
# Starting epoch 18
# Train Loss: 0.7952, Train Acc: 55.00%, Val Loss: 1.3410, Val Acc: 40.00%
# Starting epoch 19
# Train Loss: 0.8070, Train Acc: 72.50%, Val Loss: 1.3065, Val Acc: 40.00%
# Epoch 00019: reducing learning rate of group 0 to 2.0000e-09.
# Starting epoch 20
# Train Loss: 0.7308, Train Acc: 70.00%, Val Loss: 1.2494, Val Acc: 40.00%
# Starting epoch 21
# Train Loss: 0.7293, Train Acc: 70.00%, Val Loss: 1.3361, Val Acc: 40.00%
# Starting epoch 22
# Train Loss: 0.7250, Train Acc: 72.50%, Val Loss: 1.3730, Val Acc: 40.00%
# Starting epoch 23
# Train Loss: 0.7170, Train Acc: 70.00%, Val Loss: 1.3278, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 0.8587, Train Acc: 60.00%, Val Loss: 1.3408, Val Acc: 40.00%
# Starting epoch 25
# Train Loss: 0.8128, Train Acc: 55.00%, Val Loss: 1.3138, Val Acc: 40.00%
# Starting epoch 26
# Train Loss: 0.7914, Train Acc: 57.50%, Val Loss: 1.2517, Val Acc: 50.00%
# Starting epoch 27
# Train Loss: 0.7257, Train Acc: 67.50%, Val Loss: 1.2982, Val Acc: 40.00%
# Starting epoch 28
# Train Loss: 0.7769, Train Acc: 62.50%, Val Loss: 1.3419, Val Acc: 40.00%
# Starting epoch 29
# Train Loss: 0.7782, Train Acc: 65.00%, Val Loss: 1.3414, Val Acc: 40.00%
# Starting epoch 30
# Train Loss: 0.8219, Train Acc: 60.00%, Val Loss: 1.3594, Val Acc: 40.00%
# Starting epoch 31
# Train Loss: 0.8204, Train Acc: 65.00%, Val Loss: 1.3318, Val Acc: 40.00%
# Starting epoch 32
# Train Loss: 0.8526, Train Acc: 57.50%, Val Loss: 1.2618, Val Acc: 40.00%
# Starting epoch 33
# Train Loss: 0.6511, Train Acc: 75.00%, Val Loss: 1.3190, Val Acc: 40.00%
# Starting epoch 34
# Train Loss: 0.7613, Train Acc: 75.00%, Val Loss: 1.3391, Val Acc: 40.00%
# Starting epoch 35
# Train Loss: 0.7233, Train Acc: 75.00%, Val Loss: 1.2606, Val Acc: 40.00%
# Starting epoch 36
# Train Loss: 0.7581, Train Acc: 65.00%, Val Loss: 1.3102, Val Acc: 40.00%
# Starting epoch 37
# Train Loss: 0.7527, Train Acc: 57.50%, Val Loss: 1.3619, Val Acc: 40.00%
# Starting epoch 38
# Train Loss: 0.7537, Train Acc: 67.50%, Val Loss: 1.3848, Val Acc: 40.00%
# Starting epoch 39
# Train Loss: 0.8886, Train Acc: 65.00%, Val Loss: 1.3197, Val Acc: 40.00%
# Starting epoch 40
# Train Loss: 0.8690, Train Acc: 57.50%, Val Loss: 1.3699, Val Acc: 40.00%
# Starting epoch 41
# Train Loss: 0.8632, Train Acc: 60.00%, Val Loss: 1.3491, Val Acc: 40.00%
# Starting epoch 42
# Train Loss: 0.8769, Train Acc: 62.50%, Val Loss: 1.3479, Val Acc: 40.00%
# Starting epoch 43
# Train Loss: 0.7198, Train Acc: 70.00%, Val Loss: 1.3320, Val Acc: 40.00%
# Starting epoch 44
# Train Loss: 0.7708, Train Acc: 65.00%, Val Loss: 1.3054, Val Acc: 40.00%
# Starting epoch 45
# Train Loss: 0.9685, Train Acc: 45.00%, Val Loss: 1.3518, Val Acc: 40.00%
# Early stopping triggered.
# --------------------------------
# FOLD 3
# --------------------------------
# Starting epoch 1
# Train Loss: 0.8558, Train Acc: 57.50%, Val Loss: 1.3308, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 0.5645, Train Acc: 77.50%, Val Loss: 1.3062, Val Acc: 40.00%
# Starting epoch 3
# Train Loss: 0.6760, Train Acc: 70.00%, Val Loss: 1.3211, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 0.6758, Train Acc: 72.50%, Val Loss: 1.2358, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 0.6070, Train Acc: 80.00%, Val Loss: 1.2785, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 0.8388, Train Acc: 60.00%, Val Loss: 1.2782, Val Acc: 40.00%
# Starting epoch 7
# Train Loss: 0.6153, Train Acc: 75.00%, Val Loss: 1.1728, Val Acc: 40.00%
# Starting epoch 8
# Train Loss: 0.7126, Train Acc: 70.00%, Val Loss: 1.1720, Val Acc: 40.00%
# Starting epoch 9
# Train Loss: 0.6762, Train Acc: 75.00%, Val Loss: 1.1261, Val Acc: 50.00%
# Starting epoch 10
# Train Loss: 0.7445, Train Acc: 65.00%, Val Loss: 1.1739, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 0.7535, Train Acc: 75.00%, Val Loss: 1.2014, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 0.5913, Train Acc: 80.00%, Val Loss: 1.1853, Val Acc: 40.00%
# Epoch 00012: reducing learning rate of group 0 to 2.0000e-06.
# Starting epoch 13
# Train Loss: 0.5873, Train Acc: 72.50%, Val Loss: 1.1845, Val Acc: 40.00%
# Starting epoch 14
# Train Loss: 0.5817, Train Acc: 70.00%, Val Loss: 1.1814, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 0.7202, Train Acc: 67.50%, Val Loss: 1.1220, Val Acc: 40.00%
# Starting epoch 16
# Train Loss: 0.6735, Train Acc: 70.00%, Val Loss: 1.2255, Val Acc: 40.00%
# Starting epoch 17
# Train Loss: 0.6011, Train Acc: 77.50%, Val Loss: 1.1350, Val Acc: 40.00%
# Starting epoch 18
# Train Loss: 0.7333, Train Acc: 65.00%, Val Loss: 1.1233, Val Acc: 40.00%
# Epoch 00018: reducing learning rate of group 0 to 2.0000e-07.
# Starting epoch 19
# Train Loss: 0.5939, Train Acc: 72.50%, Val Loss: 1.1719, Val Acc: 40.00%
# Starting epoch 20
# Train Loss: 0.5735, Train Acc: 80.00%, Val Loss: 1.1253, Val Acc: 40.00%
# Starting epoch 21
# Train Loss: 0.7540, Train Acc: 60.00%, Val Loss: 1.0972, Val Acc: 40.00%
# Starting epoch 22
# Train Loss: 0.7114, Train Acc: 70.00%, Val Loss: 1.1724, Val Acc: 40.00%
# Starting epoch 23
# Train Loss: 0.7325, Train Acc: 62.50%, Val Loss: 1.1370, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 0.7153, Train Acc: 67.50%, Val Loss: 1.1109, Val Acc: 40.00%
# Epoch 00024: reducing learning rate of group 0 to 2.0000e-08.
# Starting epoch 25
# Train Loss: 0.5763, Train Acc: 70.00%, Val Loss: 1.1256, Val Acc: 40.00%
# Starting epoch 26
# Train Loss: 0.6746, Train Acc: 80.00%, Val Loss: 1.1390, Val Acc: 40.00%
# Starting epoch 27
# Train Loss: 0.6850, Train Acc: 67.50%, Val Loss: 1.1920, Val Acc: 40.00%
# Epoch 00027: reducing learning rate of group 0 to 2.0000e-09.
# Starting epoch 28
# Train Loss: 0.5971, Train Acc: 75.00%, Val Loss: 1.1632, Val Acc: 40.00%
# Starting epoch 29
# Train Loss: 0.7304, Train Acc: 65.00%, Val Loss: 1.1917, Val Acc: 40.00%
# Starting epoch 30
# Train Loss: 0.6740, Train Acc: 67.50%, Val Loss: 1.2189, Val Acc: 40.00%
# Starting epoch 31
# Train Loss: 0.7319, Train Acc: 57.50%, Val Loss: 1.2238, Val Acc: 40.00%
# Starting epoch 32
# Train Loss: 0.6575, Train Acc: 62.50%, Val Loss: 1.1603, Val Acc: 40.00%
# Starting epoch 33
# Train Loss: 0.6246, Train Acc: 62.50%, Val Loss: 1.1156, Val Acc: 40.00%
# Starting epoch 34
# Train Loss: 0.6316, Train Acc: 70.00%, Val Loss: 1.2021, Val Acc: 40.00%
# Starting epoch 35
# Train Loss: 0.6199, Train Acc: 75.00%, Val Loss: 1.1341, Val Acc: 40.00%
# Starting epoch 36
# Train Loss: 0.4556, Train Acc: 72.50%, Val Loss: 1.1149, Val Acc: 40.00%
# Starting epoch 37
# Train Loss: 0.7162, Train Acc: 70.00%, Val Loss: 1.1415, Val Acc: 40.00%
# Starting epoch 38
# Train Loss: 0.7119, Train Acc: 65.00%, Val Loss: 1.1142, Val Acc: 40.00%
# Starting epoch 39
# Train Loss: 0.7644, Train Acc: 70.00%, Val Loss: 1.0503, Val Acc: 40.00%
# Starting epoch 40
# Train Loss: 0.8797, Train Acc: 47.50%, Val Loss: 1.1191, Val Acc: 40.00%
# Starting epoch 41
# Train Loss: 0.7095, Train Acc: 65.00%, Val Loss: 1.1517, Val Acc: 40.00%
# Starting epoch 42
# Train Loss: 0.7135, Train Acc: 67.50%, Val Loss: 1.1583, Val Acc: 40.00%
# Starting epoch 43
# Train Loss: 0.5029, Train Acc: 80.00%, Val Loss: 1.0942, Val Acc: 40.00%
# Starting epoch 44
# Train Loss: 0.8698, Train Acc: 50.00%, Val Loss: 1.1129, Val Acc: 40.00%
# Starting epoch 45
# Train Loss: 0.6424, Train Acc: 72.50%, Val Loss: 1.1362, Val Acc: 40.00%
# Starting epoch 46
# Train Loss: 0.5501, Train Acc: 72.50%, Val Loss: 1.1014, Val Acc: 40.00%
# Starting epoch 47
# Train Loss: 0.6067, Train Acc: 75.00%, Val Loss: 1.1494, Val Acc: 40.00%
# Starting epoch 48
# Train Loss: 0.7384, Train Acc: 65.00%, Val Loss: 1.2260, Val Acc: 40.00%
# Starting epoch 49
# Train Loss: 0.6447, Train Acc: 70.00%, Val Loss: 1.1671, Val Acc: 50.00%
# Starting epoch 50
# Train Loss: 0.6026, Train Acc: 65.00%, Val Loss: 1.2336, Val Acc: 40.00%
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 0.6154, Train Acc: 75.00%, Val Loss: 1.1859, Val Acc: 40.00%
# Starting epoch 2
# Train Loss: 0.5589, Train Acc: 75.00%, Val Loss: 1.1824, Val Acc: 30.00%
# Starting epoch 3
# Train Loss: 0.7520, Train Acc: 62.50%, Val Loss: 1.0578, Val Acc: 40.00%
# Starting epoch 4
# Train Loss: 0.5710, Train Acc: 72.50%, Val Loss: 1.0946, Val Acc: 40.00%
# Starting epoch 5
# Train Loss: 0.7832, Train Acc: 62.50%, Val Loss: 1.0700, Val Acc: 40.00%
# Starting epoch 6
# Train Loss: 0.5972, Train Acc: 70.00%, Val Loss: 1.0357, Val Acc: 60.00%
# Starting epoch 7
# Train Loss: 0.7118, Train Acc: 62.50%, Val Loss: 0.9606, Val Acc: 60.00%
# Starting epoch 8
# Train Loss: 0.4554, Train Acc: 82.50%, Val Loss: 0.9725, Val Acc: 40.00%
# Starting epoch 9
# Train Loss: 0.5640, Train Acc: 77.50%, Val Loss: 0.9423, Val Acc: 50.00%
# Starting epoch 10
# Train Loss: 0.5567, Train Acc: 77.50%, Val Loss: 1.0229, Val Acc: 40.00%
# Starting epoch 11
# Train Loss: 0.6827, Train Acc: 57.50%, Val Loss: 0.9534, Val Acc: 40.00%
# Starting epoch 12
# Train Loss: 0.6089, Train Acc: 75.00%, Val Loss: 0.9652, Val Acc: 40.00%
# Epoch 00012: reducing learning rate of group 0 to 2.0000e-06.
# Starting epoch 13
# Train Loss: 0.6131, Train Acc: 70.00%, Val Loss: 1.0461, Val Acc: 30.00%
# Starting epoch 14
# Train Loss: 0.4529, Train Acc: 80.00%, Val Loss: 1.0203, Val Acc: 40.00%
# Starting epoch 15
# Train Loss: 0.5528, Train Acc: 67.50%, Val Loss: 1.0134, Val Acc: 70.00%
# Epoch 00015: reducing learning rate of group 0 to 2.0000e-07.
# Starting epoch 16
# Train Loss: 0.6260, Train Acc: 67.50%, Val Loss: 1.0118, Val Acc: 40.00%
# Starting epoch 17
# Train Loss: 0.5867, Train Acc: 70.00%, Val Loss: 0.9555, Val Acc: 30.00%
# Starting epoch 18
# Train Loss: 0.5230, Train Acc: 75.00%, Val Loss: 0.9085, Val Acc: 70.00%
# Starting epoch 19
# Train Loss: 0.5529, Train Acc: 67.50%, Val Loss: 0.9316, Val Acc: 70.00%
# Starting epoch 20
# Train Loss: 0.5455, Train Acc: 72.50%, Val Loss: 0.9831, Val Acc: 70.00%
# Starting epoch 21
# Train Loss: 0.5374, Train Acc: 72.50%, Val Loss: 1.0186, Val Acc: 40.00%
# Epoch 00021: reducing learning rate of group 0 to 2.0000e-08.
# Starting epoch 22
# Train Loss: 0.5625, Train Acc: 65.00%, Val Loss: 1.0592, Val Acc: 50.00%
# Starting epoch 23
# Train Loss: 0.7106, Train Acc: 65.00%, Val Loss: 0.9990, Val Acc: 40.00%
# Starting epoch 24
# Train Loss: 0.5790, Train Acc: 70.00%, Val Loss: 1.0092, Val Acc: 40.00%
# Epoch 00024: reducing learning rate of group 0 to 2.0000e-09.
# Starting epoch 25
# Train Loss: 0.5831, Train Acc: 72.50%, Val Loss: 1.0083, Val Acc: 50.00%
# Starting epoch 26
# Train Loss: 0.4650, Train Acc: 82.50%, Val Loss: 0.9774, Val Acc: 60.00%
# Starting epoch 27
# Train Loss: 0.7012, Train Acc: 65.00%, Val Loss: 0.9558, Val Acc: 70.00%
# Starting epoch 28
# Train Loss: 0.4984, Train Acc: 80.00%, Val Loss: 0.8972, Val Acc: 60.00%
# Starting epoch 29
# Train Loss: 0.6513, Train Acc: 65.00%, Val Loss: 1.0121, Val Acc: 50.00%
# Starting epoch 30
# Train Loss: 0.6393, Train Acc: 72.50%, Val Loss: 1.0466, Val Acc: 70.00%
# Starting epoch 31
# Train Loss: 0.5319, Train Acc: 70.00%, Val Loss: 1.0135, Val Acc: 40.00%
# Starting epoch 32
# Train Loss: 0.4765, Train Acc: 80.00%, Val Loss: 1.0416, Val Acc: 50.00%
# Starting epoch 33
# Train Loss: 0.5400, Train Acc: 67.50%, Val Loss: 0.9889, Val Acc: 40.00%
# Starting epoch 34
# Train Loss: 0.6193, Train Acc: 72.50%, Val Loss: 1.0737, Val Acc: 50.00%
# Starting epoch 35
# Train Loss: 0.6277, Train Acc: 67.50%, Val Loss: 1.1065, Val Acc: 40.00%
# Starting epoch 36
# Train Loss: 0.8615, Train Acc: 55.00%, Val Loss: 1.0272, Val Acc: 40.00%
# Starting epoch 37
# Train Loss: 0.6122, Train Acc: 65.00%, Val Loss: 0.9736, Val Acc: 50.00%
# Starting epoch 38
# Train Loss: 0.5739, Train Acc: 72.50%, Val Loss: 0.9593, Val Acc: 70.00%
# Starting epoch 39
# Train Loss: 0.6175, Train Acc: 75.00%, Val Loss: 1.0559, Val Acc: 40.00%
# Starting epoch 40
# Train Loss: 0.5714, Train Acc: 70.00%, Val Loss: 0.9892, Val Acc: 40.00%
# Starting epoch 41
# Train Loss: 0.7700, Train Acc: 62.50%, Val Loss: 1.0668, Val Acc: 40.00%
# Starting epoch 42
# Train Loss: 0.7246, Train Acc: 65.00%, Val Loss: 1.0195, Val Acc: 50.00%
# Starting epoch 43
# Train Loss: 0.5422, Train Acc: 75.00%, Val Loss: 0.9465, Val Acc: 80.00%
# Starting epoch 44
# Train Loss: 0.5352, Train Acc: 75.00%, Val Loss: 0.9733, Val Acc: 70.00%
# Starting epoch 45
# Train Loss: 0.7761, Train Acc: 62.50%, Val Loss: 0.9194, Val Acc: 60.00%
# Starting epoch 46
# Train Loss: 0.6792, Train Acc: 67.50%, Val Loss: 0.9558, Val Acc: 50.00%
# Starting epoch 47
# Train Loss: 0.8483, Train Acc: 55.00%, Val Loss: 1.0244, Val Acc: 40.00%
# Starting epoch 48
# Train Loss: 0.6545, Train Acc: 65.00%, Val Loss: 0.9685, Val Acc: 50.00%
# Starting epoch 49
# Train Loss: 0.5963, Train Acc: 75.00%, Val Loss: 1.0259, Val Acc: 40.00%
# Starting epoch 50
# Train Loss: 0.5606, Train Acc: 85.00%, Val Loss: 0.9407, Val Acc: 50.00%
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as c2_best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('c2_best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 0.8553, Test Accuracy: 67.00%
