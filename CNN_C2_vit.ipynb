# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset,DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [4 5]

# %%
model = models.vit_b_16(pretrained=True)

num_classes = 10
dropout_rate = 0.5 

model.heads = nn.Sequential(
    nn.Dropout(p=dropout_rate),  
    nn.Linear(model.heads[0].in_features, num_classes)
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=2e-5, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-5)
    criterion = nn.CrossEntropyLoss()

    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step()
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'c2_best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as c2_best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 1.8364, Train Acc: 32.50%, Val Loss: 0.7497, Val Acc: 100.00%
# Starting epoch 2
# Train Loss: 0.5491, Train Acc: 90.00%, Val Loss: 0.3319, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.2844, Train Acc: 100.00%, Val Loss: 0.2491, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.1696, Train Acc: 97.50%, Val Loss: 0.1439, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0965, Train Acc: 100.00%, Val Loss: 0.1039, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0584, Train Acc: 100.00%, Val Loss: 0.0688, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0362, Train Acc: 100.00%, Val Loss: 0.0535, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0246, Train Acc: 100.00%, Val Loss: 0.0439, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0208, Train Acc: 100.00%, Val Loss: 0.0364, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0140, Train Acc: 100.00%, Val Loss: 0.0308, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0131, Train Acc: 100.00%, Val Loss: 0.0289, Val Acc: 100.00%
# Starting epoch 12
# Train Loss: 0.0154, Train Acc: 100.00%, Val Loss: 0.0274, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0094, Train Acc: 100.00%, Val Loss: 0.0261, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0112, Train Acc: 100.00%, Val Loss: 0.0247, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0093, Train Acc: 100.00%, Val Loss: 0.0229, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0083, Train Acc: 100.00%, Val Loss: 0.0211, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0070, Train Acc: 100.00%, Val Loss: 0.0199, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0079, Train Acc: 100.00%, Val Loss: 0.0188, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0074, Train Acc: 100.00%, Val Loss: 0.0181, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0075, Train Acc: 100.00%, Val Loss: 0.0174, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0066, Train Acc: 100.00%, Val Loss: 0.0172, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0063, Train Acc: 100.00%, Val Loss: 0.0170, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0066, Train Acc: 100.00%, Val Loss: 0.0167, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.0163, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.0160, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0064, Train Acc: 100.00%, Val Loss: 0.0157, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.0153, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0069, Train Acc: 100.00%, Val Loss: 0.0151, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.0150, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0062, Train Acc: 100.00%, Val Loss: 0.0148, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0054, Train Acc: 100.00%, Val Loss: 0.0148, Val Acc: 100.00%
# Starting epoch 32
# Train Loss: 0.0043, Train Acc: 100.00%, Val Loss: 0.0147, Val Acc: 100.00%
# Starting epoch 33
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0146, Val Acc: 100.00%
# Starting epoch 34
# Train Loss: 0.0047, Train Acc: 100.00%, Val Loss: 0.0144, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.0056, Train Acc: 100.00%, Val Loss: 0.0143, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0140, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0050, Train Acc: 100.00%, Val Loss: 0.0139, Val Acc: 100.00%
# Starting epoch 38
# Train Loss: 0.0050, Train Acc: 100.00%, Val Loss: 0.0136, Val Acc: 100.00%
# Starting epoch 39
# Train Loss: 0.0048, Train Acc: 100.00%, Val Loss: 0.0134, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0041, Train Acc: 100.00%, Val Loss: 0.0133, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.0053, Train Acc: 100.00%, Val Loss: 0.0132, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0045, Train Acc: 100.00%, Val Loss: 0.0131, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0130, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0052, Train Acc: 100.00%, Val Loss: 0.0129, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0043, Train Acc: 100.00%, Val Loss: 0.0128, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.0127, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0036, Train Acc: 100.00%, Val Loss: 0.0126, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.0126, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0049, Train Acc: 100.00%, Val Loss: 0.0125, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0041, Train Acc: 100.00%, Val Loss: 0.0124, Val Acc: 100.00%
# --------------------------------
# FOLD 1
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0040, Train Acc: 100.00%, Val Loss: 0.0150, Val Acc: 100.00%
# Starting epoch 2
# Train Loss: 0.0022, Train Acc: 100.00%, Val Loss: 0.0024, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.0012, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0012, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 0.0008, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 0.0005, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.0004, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 12
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0003, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 32
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 33
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 34
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 38
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 39
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# --------------------------------
# FOLD 2
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 2
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0001, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 12
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 13
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 15
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 16
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 17
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 18
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 20
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 21
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 22
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 23
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 32
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 33
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 34
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 38
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 39
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# --------------------------------
# FOLD 3
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 2
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 3
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 4
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 6
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 7
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0000, Val Acc: 100.00%
# Starting epoch 9
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0002, Val Acc: 100.00%
# Starting epoch 10
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0077, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.1358, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.3723, Val Acc: 90.00%
# Starting epoch 13
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.0241, Val Acc: 100.00%
# Starting epoch 14
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.3019, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.4956, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.1175, Val Acc: 90.00%
# Starting epoch 17
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 0.6076, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 1.3022, Val Acc: 90.00%
# Starting epoch 19
# Train Loss: 0.1805, Train Acc: 97.50%, Val Loss: 0.3047, Val Acc: 90.00%
# Starting epoch 20
# Train Loss: 0.4767, Train Acc: 90.00%, Val Loss: 1.0063, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.2378, Train Acc: 92.50%, Val Loss: 0.5125, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.1679, Val Acc: 90.00%
# Starting epoch 23
# Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.0697, Val Acc: 100.00%
# Starting epoch 24
# Train Loss: 0.0039, Train Acc: 100.00%, Val Loss: 0.0465, Val Acc: 100.00%
# Starting epoch 25
# Train Loss: 0.0032, Train Acc: 100.00%, Val Loss: 0.0432, Val Acc: 100.00%
# Starting epoch 26
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.0432, Val Acc: 100.00%
# Starting epoch 27
# Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0435, Val Acc: 100.00%
# Starting epoch 28
# Train Loss: 0.0023, Train Acc: 100.00%, Val Loss: 0.0453, Val Acc: 100.00%
# Starting epoch 29
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.0480, Val Acc: 100.00%
# Starting epoch 30
# Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0501, Val Acc: 100.00%
# Starting epoch 31
# Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0510, Val Acc: 100.00%
# Early stopping triggered.
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 0.0274, Train Acc: 97.50%, Val Loss: 0.3448, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.0312, Train Acc: 97.50%, Val Loss: 0.1480, Val Acc: 90.00%
# Starting epoch 3
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.1576, Val Acc: 90.00%
# Starting epoch 4
# Train Loss: 0.0026, Train Acc: 100.00%, Val Loss: 0.4895, Val Acc: 90.00%
# Starting epoch 5
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.5925, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6239, Val Acc: 90.00%
# Starting epoch 7
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6383, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6463, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6516, Val Acc: 90.00%
# Starting epoch 10
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6556, Val Acc: 90.00%
# Starting epoch 11
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6573, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6590, Val Acc: 90.00%
# Starting epoch 13
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6603, Val Acc: 90.00%
# Starting epoch 14
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6615, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6623, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6635, Val Acc: 90.00%
# Starting epoch 17
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6653, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6672, Val Acc: 90.00%
# Starting epoch 19
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6699, Val Acc: 90.00%
# Starting epoch 20
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6721, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6732, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6743, Val Acc: 90.00%
# Starting epoch 23
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6771, Val Acc: 90.00%
# Starting epoch 24
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6790, Val Acc: 90.00%
# Starting epoch 25
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6806, Val Acc: 90.00%
# Starting epoch 26
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6825, Val Acc: 90.00%
# Starting epoch 27
# Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.6841, Val Acc: 90.00%
# Early stopping triggered.
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as c2_best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('c2_best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 0.5908, Test Accuracy: 89.35%
