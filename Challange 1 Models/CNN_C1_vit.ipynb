# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import Dataset,DataLoader, Subset, random_split
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device
device=set_device()
print(f"Using {device} device.")
# Out:
# Using mps device.

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
])

# %%
trainset = datasets.CIFAR10(root='./data', train=True, download=True)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        x, y = self.subset[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
selected_classes = np.random.choice(range(10), 2, replace=False)
print(selected_classes)
# Out:
# [5 8]

# %%
model = models.vit_b_16(pretrained=False)

num_classes = 10
dropout_rate = 0.5 

model.heads = nn.Sequential(
    nn.Dropout(p=dropout_rate),  
    nn.Linear(model.heads[0].in_features, num_classes)
)
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
best_val_accuracy = 0
best_model_weights = None

# %%
def train(model, device, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, targets) in enumerate(train_loader):
        data, targets = data.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
def validate(model, device, val_loader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(val_loader):
            data, targets = data.to(device), targets.to(device)
            output = model(data)
            loss = criterion(output, targets)

            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    avg_loss = total_loss / len(val_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# %%
for fold, (train_ids, val_ids) in enumerate(kfold.split(trainset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    train_indices = [i for i, (_, label) in enumerate(trainset) if label in selected_classes]

    N = 25  
    class_counts = {label: 0 for label in selected_classes}
    filtered_train_indices = []

    for i in train_indices:
        _, label = trainset[i]
        if class_counts[label] < N:
            filtered_train_indices.append(i)
            class_counts[label] += 1
    
    
    np.random.seed(42)  
    np.random.shuffle(filtered_train_indices)  
    split = int(0.8 * len(filtered_train_indices))  
    train_idx, val_idx = filtered_train_indices[:split], filtered_train_indices[split:]
    
    train_subset = Subset(trainset, train_idx)
    transformed_train_subset = TransformSubset(train_subset, transform=train_transform)

    val_subset = Subset(trainset, val_idx)
    transformed_val_subset = TransformSubset(val_subset, transform=test_transform)
    
    train_loader = DataLoader(transformed_train_subset, batch_size=5, shuffle=True)
    val_loader = DataLoader(transformed_val_subset, batch_size=5, shuffle=False)
    
    
    # Init the neural network
    model = model.to(device)
    
    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=2e-5, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-5)
    criterion = nn.CrossEntropyLoss()

    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 25

    
    # Run the training loop for defined number of epochs
    num_epochs = 50
    for epoch in range(num_epochs):
        # Print epoch
        print(f'Starting epoch {epoch+1}')
        
        # Perform training and validation
        train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
        val_loss, val_accuracy = validate(model, device, val_loader, criterion)
        
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')
        
        # Save the model if it has the best val accuracy so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict().copy()  # Save the best model weights
            patience_counter = 0  # Reset patience
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break  # Stop training if no improvement
        
        # Step the learning rate scheduler
        scheduler.step()
            
    print('--------------------------------')
    
# Save the best model weights
torch.save(best_model_weights, 'best_model.pth')
print(f'Best validation accuracy of {best_val_accuracy:.2f}% achieved, model saved as best_model.pth')
# Out:
# FOLD 0
# --------------------------------
# Starting epoch 1
# Train Loss: 0.9173, Train Acc: 65.00%, Val Loss: 0.7161, Val Acc: 80.00%
# Starting epoch 2
# Train Loss: 0.3719, Train Acc: 92.50%, Val Loss: 0.3204, Val Acc: 80.00%
# Starting epoch 3
# Train Loss: 0.2686, Train Acc: 90.00%, Val Loss: 0.3945, Val Acc: 80.00%
# Starting epoch 4
# Train Loss: 0.2175, Train Acc: 92.50%, Val Loss: 0.4575, Val Acc: 80.00%
# Starting epoch 5
# Train Loss: 0.2454, Train Acc: 92.50%, Val Loss: 0.2308, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.5438, Train Acc: 80.00%, Val Loss: 0.3069, Val Acc: 80.00%
# Starting epoch 7
# Train Loss: 0.2946, Train Acc: 85.00%, Val Loss: 0.2819, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.4002, Train Acc: 80.00%, Val Loss: 0.2422, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.3836, Train Acc: 82.50%, Val Loss: 0.5266, Val Acc: 80.00%
# Starting epoch 10
# Train Loss: 0.2680, Train Acc: 90.00%, Val Loss: 0.1932, Val Acc: 100.00%
# Starting epoch 11
# Train Loss: 0.3666, Train Acc: 82.50%, Val Loss: 0.2507, Val Acc: 80.00%
# Starting epoch 12
# Train Loss: 0.2929, Train Acc: 87.50%, Val Loss: 0.3155, Val Acc: 80.00%
# Starting epoch 13
# Train Loss: 0.2327, Train Acc: 90.00%, Val Loss: 0.2491, Val Acc: 90.00%
# Starting epoch 14
# Train Loss: 0.1984, Train Acc: 92.50%, Val Loss: 0.1589, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.1900, Train Acc: 92.50%, Val Loss: 0.2087, Val Acc: 90.00%
# Starting epoch 16
# Train Loss: 0.2710, Train Acc: 90.00%, Val Loss: 0.2883, Val Acc: 80.00%
# Starting epoch 17
# Train Loss: 0.1591, Train Acc: 95.00%, Val Loss: 0.2861, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.1669, Train Acc: 95.00%, Val Loss: 0.2496, Val Acc: 90.00%
# Starting epoch 19
# Train Loss: 0.1925, Train Acc: 95.00%, Val Loss: 0.2122, Val Acc: 90.00%
# Starting epoch 20
# Train Loss: 0.1535, Train Acc: 95.00%, Val Loss: 0.2302, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.2166, Train Acc: 92.50%, Val Loss: 0.2672, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.1344, Train Acc: 95.00%, Val Loss: 0.2208, Val Acc: 90.00%
# Starting epoch 23
# Train Loss: 0.1670, Train Acc: 92.50%, Val Loss: 0.2160, Val Acc: 90.00%
# Starting epoch 24
# Train Loss: 0.1395, Train Acc: 92.50%, Val Loss: 0.1702, Val Acc: 90.00%
# Starting epoch 25
# Train Loss: 0.1279, Train Acc: 92.50%, Val Loss: 0.1540, Val Acc: 90.00%
# Starting epoch 26
# Train Loss: 0.1787, Train Acc: 95.00%, Val Loss: 0.1559, Val Acc: 90.00%
# Starting epoch 27
# Train Loss: 0.1899, Train Acc: 90.00%, Val Loss: 0.1517, Val Acc: 90.00%
# Starting epoch 28
# Train Loss: 0.1297, Train Acc: 90.00%, Val Loss: 0.1542, Val Acc: 90.00%
# Starting epoch 29
# Train Loss: 0.0795, Train Acc: 97.50%, Val Loss: 0.1569, Val Acc: 90.00%
# Starting epoch 30
# Train Loss: 0.1193, Train Acc: 95.00%, Val Loss: 0.1377, Val Acc: 90.00%
# Starting epoch 31
# Train Loss: 0.1113, Train Acc: 97.50%, Val Loss: 0.1310, Val Acc: 90.00%
# Starting epoch 32
# Train Loss: 0.0916, Train Acc: 97.50%, Val Loss: 0.1334, Val Acc: 90.00%
# Starting epoch 33
# Train Loss: 0.0884, Train Acc: 95.00%, Val Loss: 0.1279, Val Acc: 90.00%
# Starting epoch 34
# Train Loss: 0.1037, Train Acc: 97.50%, Val Loss: 0.1157, Val Acc: 100.00%
# Starting epoch 35
# Train Loss: 0.1112, Train Acc: 92.50%, Val Loss: 0.1110, Val Acc: 100.00%
# Starting epoch 36
# Train Loss: 0.0746, Train Acc: 100.00%, Val Loss: 0.1069, Val Acc: 100.00%
# Starting epoch 37
# Train Loss: 0.0801, Train Acc: 95.00%, Val Loss: 0.1106, Val Acc: 90.00%
# Starting epoch 38
# Train Loss: 0.0780, Train Acc: 97.50%, Val Loss: 0.1161, Val Acc: 90.00%
# Starting epoch 39
# Train Loss: 0.0600, Train Acc: 97.50%, Val Loss: 0.1128, Val Acc: 100.00%
# Starting epoch 40
# Train Loss: 0.0568, Train Acc: 100.00%, Val Loss: 0.1086, Val Acc: 100.00%
# Starting epoch 41
# Train Loss: 0.1026, Train Acc: 97.50%, Val Loss: 0.1067, Val Acc: 100.00%
# Starting epoch 42
# Train Loss: 0.0619, Train Acc: 97.50%, Val Loss: 0.0998, Val Acc: 100.00%
# Starting epoch 43
# Train Loss: 0.0462, Train Acc: 100.00%, Val Loss: 0.1004, Val Acc: 100.00%
# Starting epoch 44
# Train Loss: 0.0949, Train Acc: 97.50%, Val Loss: 0.1043, Val Acc: 100.00%
# Starting epoch 45
# Train Loss: 0.0410, Train Acc: 100.00%, Val Loss: 0.1062, Val Acc: 100.00%
# Starting epoch 46
# Train Loss: 0.0647, Train Acc: 97.50%, Val Loss: 0.1055, Val Acc: 100.00%
# Starting epoch 47
# Train Loss: 0.0577, Train Acc: 97.50%, Val Loss: 0.1063, Val Acc: 100.00%
# Starting epoch 48
# Train Loss: 0.0490, Train Acc: 100.00%, Val Loss: 0.1057, Val Acc: 100.00%
# Starting epoch 49
# Train Loss: 0.0514, Train Acc: 97.50%, Val Loss: 0.1016, Val Acc: 100.00%
# Starting epoch 50
# Train Loss: 0.0433, Train Acc: 97.50%, Val Loss: 0.1023, Val Acc: 90.00%
# --------------------------------
# FOLD 1
# --------------------------------
# Starting epoch 1
# Train Loss: 0.2904, Train Acc: 87.50%, Val Loss: 0.2552, Val Acc: 90.00%
# Starting epoch 2
# Train Loss: 0.1445, Train Acc: 95.00%, Val Loss: 0.5916, Val Acc: 80.00%
# Starting epoch 3
# Train Loss: 0.2714, Train Acc: 92.50%, Val Loss: 0.3080, Val Acc: 80.00%
# Starting epoch 4
# Train Loss: 0.1522, Train Acc: 95.00%, Val Loss: 0.7203, Val Acc: 80.00%
# Starting epoch 5
# Train Loss: 0.2149, Train Acc: 95.00%, Val Loss: 0.3307, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.1185, Train Acc: 92.50%, Val Loss: 0.2452, Val Acc: 90.00%
# Starting epoch 7
# Train Loss: 0.0257, Train Acc: 100.00%, Val Loss: 0.1683, Val Acc: 100.00%
# Starting epoch 8
# Train Loss: 0.1275, Train Acc: 95.00%, Val Loss: 0.4685, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.2202, Train Acc: 92.50%, Val Loss: 0.5421, Val Acc: 80.00%
# Starting epoch 10
# Train Loss: 0.0334, Train Acc: 100.00%, Val Loss: 0.3609, Val Acc: 70.00%
# Starting epoch 11
# Train Loss: 0.2251, Train Acc: 92.50%, Val Loss: 0.3348, Val Acc: 90.00%
# Starting epoch 12
# Train Loss: 0.0918, Train Acc: 97.50%, Val Loss: 0.5032, Val Acc: 70.00%
# Starting epoch 13
# Train Loss: 0.1022, Train Acc: 97.50%, Val Loss: 0.4561, Val Acc: 70.00%
# Starting epoch 14
# Train Loss: 0.0968, Train Acc: 95.00%, Val Loss: 0.4027, Val Acc: 90.00%
# Starting epoch 15
# Train Loss: 0.0423, Train Acc: 100.00%, Val Loss: 0.5276, Val Acc: 80.00%
# Starting epoch 16
# Train Loss: 0.0511, Train Acc: 100.00%, Val Loss: 0.7711, Val Acc: 80.00%
# Starting epoch 17
# Train Loss: 0.0574, Train Acc: 97.50%, Val Loss: 0.8493, Val Acc: 80.00%
# Starting epoch 18
# Train Loss: 0.0209, Train Acc: 100.00%, Val Loss: 0.8983, Val Acc: 80.00%
# Starting epoch 19
# Train Loss: 0.0332, Train Acc: 97.50%, Val Loss: 0.8415, Val Acc: 80.00%
# Starting epoch 20
# Train Loss: 0.0212, Train Acc: 100.00%, Val Loss: 0.8739, Val Acc: 80.00%
# Starting epoch 21
# Train Loss: 0.0032, Train Acc: 100.00%, Val Loss: 0.8794, Val Acc: 80.00%
# Starting epoch 22
# Train Loss: 0.0045, Train Acc: 100.00%, Val Loss: 0.8811, Val Acc: 80.00%
# Starting epoch 23
# Train Loss: 0.0061, Train Acc: 100.00%, Val Loss: 0.8810, Val Acc: 80.00%
# Starting epoch 24
# Train Loss: 0.0306, Train Acc: 97.50%, Val Loss: 0.7644, Val Acc: 80.00%
# Starting epoch 25
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.7748, Val Acc: 80.00%
# Starting epoch 26
# Train Loss: 0.0559, Train Acc: 97.50%, Val Loss: 0.7100, Val Acc: 80.00%
# Starting epoch 27
# Train Loss: 0.0159, Train Acc: 100.00%, Val Loss: 0.6486, Val Acc: 80.00%
# Starting epoch 28
# Train Loss: 0.0119, Train Acc: 100.00%, Val Loss: 0.6876, Val Acc: 80.00%
# Starting epoch 29
# Train Loss: 0.0351, Train Acc: 100.00%, Val Loss: 0.9162, Val Acc: 70.00%
# Starting epoch 30
# Train Loss: 0.0361, Train Acc: 97.50%, Val Loss: 1.1976, Val Acc: 70.00%
# Starting epoch 31
# Train Loss: 0.0853, Train Acc: 97.50%, Val Loss: 1.1865, Val Acc: 70.00%
# Starting epoch 32
# Train Loss: 0.0105, Train Acc: 100.00%, Val Loss: 1.0596, Val Acc: 70.00%
# Early stopping triggered.
# --------------------------------
# FOLD 2
# --------------------------------
# Starting epoch 1
# Train Loss: 0.4618, Train Acc: 92.50%, Val Loss: 0.5664, Val Acc: 80.00%
# Starting epoch 2
# Train Loss: 0.0637, Train Acc: 95.00%, Val Loss: 0.5304, Val Acc: 80.00%
# Starting epoch 3
# Train Loss: 0.1050, Train Acc: 97.50%, Val Loss: 0.3602, Val Acc: 90.00%
# Starting epoch 4
# Train Loss: 0.0354, Train Acc: 100.00%, Val Loss: 0.2689, Val Acc: 90.00%
# Starting epoch 5
# Train Loss: 0.0381, Train Acc: 100.00%, Val Loss: 0.3369, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0561, Train Acc: 97.50%, Val Loss: 0.5414, Val Acc: 80.00%
# Starting epoch 7
# Train Loss: 0.1437, Train Acc: 92.50%, Val Loss: 0.2366, Val Acc: 80.00%
# Starting epoch 8
# Train Loss: 0.0471, Train Acc: 97.50%, Val Loss: 0.6890, Val Acc: 80.00%
# Starting epoch 9
# Train Loss: 0.3208, Train Acc: 95.00%, Val Loss: 0.4811, Val Acc: 80.00%
# Starting epoch 10
# Train Loss: 0.1787, Train Acc: 92.50%, Val Loss: 0.1116, Val Acc: 90.00%
# Starting epoch 11
# Train Loss: 0.0939, Train Acc: 95.00%, Val Loss: 0.2985, Val Acc: 80.00%
# Starting epoch 12
# Train Loss: 0.0452, Train Acc: 97.50%, Val Loss: 0.2691, Val Acc: 80.00%
# Starting epoch 13
# Train Loss: 0.0233, Train Acc: 100.00%, Val Loss: 0.4139, Val Acc: 80.00%
# Starting epoch 14
# Train Loss: 0.0530, Train Acc: 97.50%, Val Loss: 0.4397, Val Acc: 80.00%
# Starting epoch 15
# Train Loss: 0.0506, Train Acc: 97.50%, Val Loss: 0.4871, Val Acc: 70.00%
# Starting epoch 16
# Train Loss: 0.0094, Train Acc: 100.00%, Val Loss: 0.6062, Val Acc: 70.00%
# Starting epoch 17
# Train Loss: 0.0616, Train Acc: 97.50%, Val Loss: 0.3618, Val Acc: 90.00%
# Starting epoch 18
# Train Loss: 0.0335, Train Acc: 97.50%, Val Loss: 0.3059, Val Acc: 80.00%
# Starting epoch 19
# Train Loss: 0.0059, Train Acc: 100.00%, Val Loss: 0.3126, Val Acc: 80.00%
# Starting epoch 20
# Train Loss: 0.0023, Train Acc: 100.00%, Val Loss: 0.3367, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.0024, Train Acc: 100.00%, Val Loss: 0.3423, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.0018, Train Acc: 100.00%, Val Loss: 0.3431, Val Acc: 90.00%
# Starting epoch 23
# Train Loss: 0.0033, Train Acc: 100.00%, Val Loss: 0.3495, Val Acc: 90.00%
# Starting epoch 24
# Train Loss: 0.0367, Train Acc: 97.50%, Val Loss: 0.3266, Val Acc: 80.00%
# Starting epoch 25
# Train Loss: 0.0046, Train Acc: 100.00%, Val Loss: 0.3575, Val Acc: 80.00%
# Starting epoch 26
# Train Loss: 0.0055, Train Acc: 100.00%, Val Loss: 0.3706, Val Acc: 80.00%
# Starting epoch 27
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.3661, Val Acc: 80.00%
# Starting epoch 28
# Train Loss: 0.0049, Train Acc: 100.00%, Val Loss: 0.3688, Val Acc: 80.00%
# Starting epoch 29
# Train Loss: 0.0225, Train Acc: 97.50%, Val Loss: 0.4871, Val Acc: 70.00%
# Starting epoch 30
# Train Loss: 0.0025, Train Acc: 100.00%, Val Loss: 0.5538, Val Acc: 70.00%
# Starting epoch 31
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.5864, Val Acc: 70.00%
# Starting epoch 32
# Train Loss: 0.0295, Train Acc: 97.50%, Val Loss: 0.6537, Val Acc: 70.00%
# Starting epoch 33
# Train Loss: 0.0063, Train Acc: 100.00%, Val Loss: 0.7479, Val Acc: 70.00%
# Starting epoch 34
# Train Loss: 0.0070, Train Acc: 100.00%, Val Loss: 0.7858, Val Acc: 70.00%
# Starting epoch 35
# Train Loss: 0.0020, Train Acc: 100.00%, Val Loss: 0.7970, Val Acc: 70.00%
# Early stopping triggered.
# --------------------------------
# FOLD 3
# --------------------------------
# Starting epoch 1
# Train Loss: 0.2511, Train Acc: 95.00%, Val Loss: 0.6953, Val Acc: 80.00%
# Starting epoch 2
# Train Loss: 0.6225, Train Acc: 87.50%, Val Loss: 0.5081, Val Acc: 90.00%
# Starting epoch 3
# Train Loss: 0.0066, Train Acc: 100.00%, Val Loss: 0.3389, Val Acc: 90.00%
# Starting epoch 4
# Train Loss: 0.0984, Train Acc: 95.00%, Val Loss: 0.4989, Val Acc: 80.00%
# Starting epoch 5
# Train Loss: 0.0664, Train Acc: 97.50%, Val Loss: 0.1769, Val Acc: 90.00%
# Starting epoch 6
# Train Loss: 0.0182, Train Acc: 100.00%, Val Loss: 0.1999, Val Acc: 90.00%
# Starting epoch 7
# Train Loss: 0.0244, Train Acc: 100.00%, Val Loss: 0.2230, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0267, Train Acc: 97.50%, Val Loss: 0.1927, Val Acc: 90.00%
# Starting epoch 9
# Train Loss: 0.0059, Train Acc: 100.00%, Val Loss: 0.2067, Val Acc: 90.00%
# Starting epoch 10
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.2297, Val Acc: 80.00%
# Starting epoch 11
# Train Loss: 0.0044, Train Acc: 100.00%, Val Loss: 0.2399, Val Acc: 80.00%
# Starting epoch 12
# Train Loss: 0.0051, Train Acc: 100.00%, Val Loss: 0.2525, Val Acc: 80.00%
# Starting epoch 13
# Train Loss: 0.0040, Train Acc: 100.00%, Val Loss: 0.2707, Val Acc: 80.00%
# Starting epoch 14
# Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.2935, Val Acc: 80.00%
# Starting epoch 15
# Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.3053, Val Acc: 80.00%
# Starting epoch 16
# Train Loss: 0.0499, Train Acc: 97.50%, Val Loss: 0.7183, Val Acc: 80.00%
# Starting epoch 17
# Train Loss: 0.1531, Train Acc: 97.50%, Val Loss: 0.8094, Val Acc: 80.00%
# Starting epoch 18
# Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.1081, Val Acc: 100.00%
# Starting epoch 19
# Train Loss: 0.0500, Train Acc: 97.50%, Val Loss: 0.2350, Val Acc: 90.00%
# Starting epoch 20
# Train Loss: 0.0032, Train Acc: 100.00%, Val Loss: 0.3349, Val Acc: 80.00%
# Starting epoch 21
# Train Loss: 0.0037, Train Acc: 100.00%, Val Loss: 0.3471, Val Acc: 80.00%
# Starting epoch 22
# Train Loss: 0.0015, Train Acc: 100.00%, Val Loss: 0.3514, Val Acc: 80.00%
# Starting epoch 23
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.3497, Val Acc: 80.00%
# Starting epoch 24
# Train Loss: 0.0020, Train Acc: 100.00%, Val Loss: 0.3398, Val Acc: 80.00%
# Starting epoch 25
# Train Loss: 0.0151, Train Acc: 100.00%, Val Loss: 0.2901, Val Acc: 90.00%
# Starting epoch 26
# Train Loss: 0.0025, Train Acc: 100.00%, Val Loss: 0.2157, Val Acc: 90.00%
# Starting epoch 27
# Train Loss: 0.0207, Train Acc: 100.00%, Val Loss: 0.2351, Val Acc: 90.00%
# Starting epoch 28
# Train Loss: 0.0133, Train Acc: 100.00%, Val Loss: 0.2450, Val Acc: 90.00%
# Starting epoch 29
# Train Loss: 0.0032, Train Acc: 100.00%, Val Loss: 0.2705, Val Acc: 90.00%
# Starting epoch 30
# Train Loss: 0.0011, Train Acc: 100.00%, Val Loss: 0.3001, Val Acc: 90.00%
# Starting epoch 31
# Train Loss: 0.0179, Train Acc: 100.00%, Val Loss: 0.3243, Val Acc: 90.00%
# Starting epoch 32
# Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.3536, Val Acc: 90.00%
# Starting epoch 33
# Train Loss: 0.0014, Train Acc: 100.00%, Val Loss: 0.3663, Val Acc: 90.00%
# Starting epoch 34
# Train Loss: 0.0018, Train Acc: 100.00%, Val Loss: 0.3682, Val Acc: 90.00%
# Starting epoch 35
# Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.3699, Val Acc: 90.00%
# Starting epoch 36
# Train Loss: 0.0200, Train Acc: 100.00%, Val Loss: 0.3591, Val Acc: 90.00%
# Starting epoch 37
# Train Loss: 0.0036, Train Acc: 100.00%, Val Loss: 0.3073, Val Acc: 90.00%
# Starting epoch 38
# Train Loss: 0.0141, Train Acc: 100.00%, Val Loss: 0.2740, Val Acc: 90.00%
# Starting epoch 39
# Train Loss: 0.0138, Train Acc: 100.00%, Val Loss: 0.2160, Val Acc: 90.00%
# Starting epoch 40
# Train Loss: 0.0153, Train Acc: 100.00%, Val Loss: 0.1883, Val Acc: 80.00%
# Starting epoch 41
# Train Loss: 0.0042, Train Acc: 100.00%, Val Loss: 0.1939, Val Acc: 80.00%
# Starting epoch 42
# Train Loss: 0.0065, Train Acc: 100.00%, Val Loss: 0.1993, Val Acc: 80.00%
# Starting epoch 43
# Train Loss: 0.0058, Train Acc: 100.00%, Val Loss: 0.2044, Val Acc: 80.00%
# Early stopping triggered.
# --------------------------------
# FOLD 4
# --------------------------------
# Starting epoch 1
# Train Loss: 0.2243, Train Acc: 97.50%, Val Loss: 1.2379, Val Acc: 80.00%
# Starting epoch 2
# Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.7652, Val Acc: 90.00%
# Starting epoch 3
# Train Loss: 0.2602, Train Acc: 95.00%, Val Loss: 0.3465, Val Acc: 80.00%
# Starting epoch 4
# Train Loss: 0.1006, Train Acc: 97.50%, Val Loss: 0.1671, Val Acc: 100.00%
# Starting epoch 5
# Train Loss: 0.1378, Train Acc: 92.50%, Val Loss: 0.3931, Val Acc: 80.00%
# Starting epoch 6
# Train Loss: 0.0041, Train Acc: 100.00%, Val Loss: 0.4819, Val Acc: 80.00%
# Starting epoch 7
# Train Loss: 0.1273, Train Acc: 92.50%, Val Loss: 0.5238, Val Acc: 90.00%
# Starting epoch 8
# Train Loss: 0.0885, Train Acc: 97.50%, Val Loss: 0.9123, Val Acc: 80.00%
# Starting epoch 9
# Train Loss: 0.0444, Train Acc: 95.00%, Val Loss: 0.4101, Val Acc: 80.00%
# Starting epoch 10
# Train Loss: 0.0088, Train Acc: 100.00%, Val Loss: 0.2925, Val Acc: 80.00%
# Starting epoch 11
# Train Loss: 0.0116, Train Acc: 100.00%, Val Loss: 0.2746, Val Acc: 80.00%
# Starting epoch 12
# Train Loss: 0.0753, Train Acc: 97.50%, Val Loss: 0.6123, Val Acc: 80.00%
# Starting epoch 13
# Train Loss: 0.0046, Train Acc: 100.00%, Val Loss: 0.9080, Val Acc: 80.00%
# Starting epoch 14
# Train Loss: 0.0167, Train Acc: 100.00%, Val Loss: 1.0125, Val Acc: 80.00%
# Starting epoch 15
# Train Loss: 0.0110, Train Acc: 100.00%, Val Loss: 0.9862, Val Acc: 70.00%
# Starting epoch 16
# Train Loss: 0.0015, Train Acc: 100.00%, Val Loss: 0.9379, Val Acc: 70.00%
# Starting epoch 17
# Train Loss: 0.0016, Train Acc: 100.00%, Val Loss: 0.8991, Val Acc: 70.00%
# Starting epoch 18
# Train Loss: 0.0060, Train Acc: 100.00%, Val Loss: 0.8638, Val Acc: 70.00%
# Starting epoch 19
# Train Loss: 0.0040, Train Acc: 100.00%, Val Loss: 0.7772, Val Acc: 70.00%
# Starting epoch 20
# Train Loss: 0.0656, Train Acc: 97.50%, Val Loss: 0.4549, Val Acc: 90.00%
# Starting epoch 21
# Train Loss: 0.0184, Train Acc: 100.00%, Val Loss: 0.4412, Val Acc: 90.00%
# Starting epoch 22
# Train Loss: 0.0135, Train Acc: 100.00%, Val Loss: 0.4130, Val Acc: 80.00%
# Starting epoch 23
# Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.3431, Val Acc: 80.00%
# Starting epoch 24
# Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.3552, Val Acc: 80.00%
# Starting epoch 25
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.3813, Val Acc: 70.00%
# Starting epoch 26
# Train Loss: 0.0106, Train Acc: 100.00%, Val Loss: 0.5435, Val Acc: 80.00%
# Starting epoch 27
# Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.7265, Val Acc: 80.00%
# Starting epoch 28
# Train Loss: 0.0037, Train Acc: 100.00%, Val Loss: 0.7813, Val Acc: 80.00%
# Starting epoch 29
# Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.7868, Val Acc: 80.00%
# Early stopping triggered.
# --------------------------------
# Best validation accuracy of 0.00% achieved, model saved as best_model.pth

# %%
model = model.to(device)
model.load_state_dict(torch.load('best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_indices = [i for i, (_, label) in enumerate(testset) if label in selected_classes]
N = 1000 
class_counts = {label: 0 for label in selected_classes}
filtered_train_indices = []

for i in test_indices:
    _, label = testset[i]
    if class_counts[label] < N:
        filtered_train_indices.append(i)
        class_counts[label] += 1

test_subset = Subset(testset, filtered_train_indices)
test_loader = DataLoader(test_subset, batch_size=50, shuffle=False)

# %%
# Ensure the model is in evaluation mode
model.eval()

# Assuming the test_loader and the device are already defined
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Evaluation
test_loss = 0
correct = 0
total = 0

# No gradient is needed for evaluation
with torch.no_grad():
    for data, targets in test_loader:
        # Move data and targets to the correct device
        data = data.to(device)
        targets = targets.to(device)

        # Compute the model output
        output = model(data)
        loss = criterion(output, targets)
        
        # Accumulate the loss and calculate accuracy
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

# Calculate average loss and accuracy percentage
avg_loss = test_loss / len(test_loader)
accuracy = 100. * correct / total

# Print the test loss and accuracy
print(f'Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 1.0348, Test Accuracy: 82.90%
